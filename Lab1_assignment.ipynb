# %%
import csv
import hashlib
import time
import random
import string
import unittest
from datetime import datetime
from typing import List, Dict, Optional



def encrypt_password(password: str) -> str:
    """Encrypt password using SHA-256 hashing"""
    return hashlib.sha256(password.encode()).hexdigest()

def verify_password(stored_password: str, provided_password: str) -> bool:
    """Verify if provided password matches stored encrypted password"""
    return stored_password == encrypt_password(provided_password)

def generate_unique_id(prefix: str) -> str:
    """Generate unique ID with timestamp and random string"""
    timestamp = datetime.now().strftime("%Y%m%d%H%M%S")
    random_str = ''.join(random.choices(string.ascii_uppercase + string.digits, k=4))
    return f"{prefix}_{timestamp}_{random_str}"


# Grade Class


class Grade:
    """Represents grade information with ranges"""

    def __init__(self, grade_id: str, grade: str, min_marks: int, max_marks: int):
        self.grade_id = grade_id
        self.grade = grade
        self.min_marks = min_marks
        self.max_marks = max_marks

    def display_grade_info(self):
        """Display grade information"""
        print(f"Grade: {self.grade}, Range: {self.min_marks}-{self.max_marks}")

    @staticmethod
    def get_grade_from_marks(marks: float) -> str:
        """Convert marks to letter grade"""
        if marks >= 90:
            return 'A'
        elif marks >= 80:
            return 'B'
        elif marks >= 70:
            return 'C'
        elif marks >= 60:
            return 'D'
        else:
            return 'F'

    def to_dict(self) -> dict:
        """Convert Grade object to dictionary"""
        return {
            'grade_id': self.grade_id,
            'grade': self.grade,
            'min_marks': self.min_marks,
            'max_marks': self.max_marks
        }

# Course Class


class Course:
    """Represents course information"""

    def __init__(self, course_id: str, course_name: str, credits: int, description: str = ""):
        if not course_id:
            raise ValueError("Course ID cannot be empty")
        self.course_id = course_id
        self.course_name = course_name
        self.credits = credits
        self.description = description

    def display_course_details(self):
        """Display course information"""
        print(f"\nCourse ID: {self.course_id}")
        print(f"Course Name: {self.course_name}")
        print(f"Credits: {self.credits}")
        print(f"Description: {self.description}")

    def to_dict(self) -> dict:
        """Convert Course object to dictionary"""
        return {
            'course_id': self.course_id,
            'course_name': self.course_name,
            'credits': self.credits,
            'description': self.description
        }


# Professor Class


class Professor:
    """Represents professor information - HAS-A relationship with Course"""

    def __init__(self, professor_id: str, name: str, email: str, rank: str, course_ids: List[str] = None):
        if not professor_id or not email:
            raise ValueError("Professor ID and Email cannot be empty")
        self.professor_id = professor_id
        self.name = name
        self.email = email
        self.rank = rank
        self.course_ids = course_ids if course_ids else []

    def display_professor_details(self):
        """Display professor information"""
        print(f"\nProfessor ID: {self.professor_id}")
        print(f"Name: {self.name}")
        print(f"Email: {self.email}")
        print(f"Rank: {self.rank}")
        print(f"Courses: {', '.join(self.course_ids)}")

    def add_course(self, course_id: str):
        """Add course to professor's teaching list"""
        if course_id not in self.course_ids:
            self.course_ids.append(course_id)

    def remove_course(self, course_id: str):
        """Remove course from professor's teaching list"""
        if course_id in self.course_ids:
            self.course_ids.remove(course_id)

    def to_dict(self) -> dict:
        """Convert Professor object to dictionary"""
        return {
            'professor_id': self.professor_id,
            'name': self.name,
            'email': self.email,
            'rank': self.rank,
            'course_ids': ','.join(self.course_ids)
        }


# Student Class


class Student:
    """Represents student information with grades - HAS-A relationship with Course and Grade"""

    def __init__(self, student_id: str, first_name: str, last_name: str, email: str):
        if not student_id or not email:
            raise ValueError("Student ID and Email cannot be empty")
        self.student_id = student_id
        self.first_name = first_name
        self.last_name = last_name
        self.email = email
        self.courses = {}  # {course_id: {'marks': float, 'grade': str}}

    def display_student_info(self):
        """Display student information"""
        print(f"\nStudent ID: {self.student_id}")
        print(f"Name: {self.first_name} {self.last_name}")
        print(f"Email: {self.email}")
        if self.courses:
            print("Enrolled Courses:")
            for course_id, data in self.courses.items():
                print(f"  {course_id}: Marks={data['marks']}, Grade={data['grade']}")
        else:
            print("No courses enrolled")

    def add_course_grade(self, course_id: str, marks: float):
        """Add or update course grade for student"""
        grade = Grade.get_grade_from_marks(marks)
        self.courses[course_id] = {'marks': marks, 'grade': grade}

    def remove_course(self, course_id: str):
        """Remove course from student's record"""
        if course_id in self.courses:
            del self.courses[course_id]

    def get_average_marks(self) -> float:
        """Calculate average marks across all courses"""
        if not self.courses:
            return 0.0
        total = sum(data['marks'] for data in self.courses.values())
        return total / len(self.courses)

    def to_dict(self) -> dict:
        """Convert Student object to dictionary for CSV"""
        course_ids = ','.join(self.courses.keys())
        grades = ','.join(data['grade'] for data in self.courses.values())
        marks = ','.join(str(data['marks']) for data in self.courses.values())

        return {
            'student_id': self.student_id,
            'first_name': self.first_name,
            'last_name': self.last_name,
            'email': self.email,
            'course_ids': course_ids,
            'grades': grades,
            'marks': marks
        }


# LoginUser Class


class LoginUser:
    """Handles user authentication - IS-A relationship (can be Student, Professor, or Admin)"""

    def __init__(self, email: str, password: str, role: str):
        self.email = email
        self.password_hash = encrypt_password(password)
        self.role = role
        self.is_logged_in = False

    def login(self, provided_password: str) -> bool:
        """Authenticate user with password"""
        if verify_password(self.password_hash, provided_password):
            self.is_logged_in = True
            print(f"Login successful! Welcome {self.email}")
            return True
        else:
            print("Invalid password")
            return False

    def logout(self):
        """Logout user"""
        self.is_logged_in = False
        print("Logged out successfully")

    def change_password(self, old_password: str, new_password: str) -> bool:
        """Change user password"""
        if verify_password(self.password_hash, old_password):
            self.password_hash = encrypt_password(new_password)
            print("Password changed successfully")
            return True
        else:
            print("Old password incorrect")
            return False

    def to_dict(self) -> dict:
        """Convert LoginUser to dictionary"""
        return {
            'email': self.email,
            'password': self.password_hash,
            'role': self.role
        }

# CheckMyGrade Application - Main Class

class CheckMyGradeApp:
    """Main application class managing all entities"""

    def __init__(self):
        self.students = []
        self.courses = []
        self.professors = []
        self.users = []
        self.grades = self._initialize_grades()
        self.current_user = None

    def _initialize_grades(self) -> List[Grade]:
        """Initialize standard grading system"""
        return [
            Grade("G1", "A", 90, 100),
            Grade("G2", "B", 80, 89),
            Grade("G3", "C", 70, 79),
            Grade("G4", "D", 60, 69),
            Grade("G5", "F", 0, 59)
        ]

    # ==================== Student Operations ====================

    def add_student(self, first_name: str, last_name: str, email: str) -> Student:
        """Add new student to the system"""
        if any(s.email == email for s in self.students):
            raise ValueError(f"Student with email {email} already exists")

        student_id = generate_unique_id("STU")
        student = Student(student_id, first_name, last_name, email)
        self.students.append(student)
        print(f"Student {first_name} {last_name} added successfully with ID: {student_id}")
        return student

    def delete_student(self, student_id: str) -> bool:
        """Delete student by ID"""
        for i, student in enumerate(self.students):
            if student.student_id == student_id:
                self.students.pop(i)
                print(f"Student {student_id} deleted successfully")
                return True
        print(f"Student {student_id} not found")
        return False

    def update_student(self, student_id: str, **kwargs) -> bool:
        """Update student information"""
        student = self.search_student_by_id(student_id)
        if student:
            if 'first_name' in kwargs:
                student.first_name = kwargs['first_name']
            if 'last_name' in kwargs:
                student.last_name = kwargs['last_name']
            if 'email' in kwargs:
                student.email = kwargs['email']
            print(f"Student {student_id} updated successfully")
            return True
        print(f"Student {student_id} not found")
        return False

    def search_student_by_id(self, student_id: str) -> Optional[Student]:
        """Search student by ID - Linear Search"""
        for student in self.students:
            if student.student_id == student_id:
                return student
        return None

    def search_student_by_email(self, email: str) -> Optional[Student]:
        """Search student by email"""
        for student in self.students:
            if student.email == email:
                return student
        return None

    def sort_students_by_name(self, reverse: bool = False):
        """Sort students by name using bubble sort"""
        n = len(self.students)
        for i in range(n):
            for j in range(0, n - i - 1):
                name1 = f"{self.students[j].first_name} {self.students[j].last_name}"
                name2 = f"{self.students[j + 1].first_name} {self.students[j + 1].last_name}"
                if (name1 > name2 and not reverse) or (name1 < name2 and reverse):
                    self.students[j], self.students[j + 1] = self.students[j + 1], self.students[j]

    def sort_students_by_marks(self, reverse: bool = False):
        """Sort students by average marks using selection sort"""
        n = len(self.students)
        for i in range(n):
            target_idx = i
            for j in range(i + 1, n):
                avg1 = self.students[target_idx].get_average_marks()
                avg2 = self.students[j].get_average_marks()
                if (avg2 > avg1 and not reverse) or (avg2 < avg1 and reverse):
                    target_idx = j
            self.students[i], self.students[target_idx] = self.students[target_idx], self.students[i]

    # ==================== Course Operations ====================

    def add_course(self, course_id: str, course_name: str, credits: int, description: str = "") -> Course:
        """Add new course"""
        if any(c.course_id == course_id for c in self.courses):
            raise ValueError(f"Course with ID {course_id} already exists")

        course = Course(course_id, course_name, credits, description)
        self.courses.append(course)
        print(f"Course {course_name} added successfully")
        return course

    def delete_course(self, course_id: str) -> bool:
        """Delete course by ID"""
        for i, course in enumerate(self.courses):
            if course.course_id == course_id:
                self.courses.pop(i)
                print(f"Course {course_id} deleted successfully")
                return True
        print(f"Course {course_id} not found")
        return False

    def update_course(self, course_id: str, **kwargs) -> bool:
        """Update course information"""
        course = self.search_course_by_id(course_id)
        if course:
            if 'course_name' in kwargs:
                course.course_name = kwargs['course_name']
            if 'credits' in kwargs:
                course.credits = kwargs['credits']
            if 'description' in kwargs:
                course.description = kwargs['description']
            print(f"Course {course_id} updated successfully")
            return True
        print(f"Course {course_id} not found")
        return False

    def search_course_by_id(self, course_id: str) -> Optional[Course]:
        """Search course by ID"""
        for course in self.courses:
            if course.course_id == course_id:
                return course
        return None

    # ==================== Professor Operations ====================

    def add_professor(self, name: str, email: str, rank: str, course_ids: List[str] = None) -> Professor:
        """Add new professor"""
        if any(p.email == email for p in self.professors):
            raise ValueError(f"Professor with email {email} already exists")

        professor_id = generate_unique_id("PROF")
        professor = Professor(professor_id, name, email, rank, course_ids)
        self.professors.append(professor)
        print(f"Professor {name} added successfully with ID: {professor_id}")
        return professor

    def delete_professor(self, professor_id: str) -> bool:
        """Delete professor by ID"""
        for i, prof in enumerate(self.professors):
            if prof.professor_id == professor_id:
                self.professors.pop(i)
                print(f"Professor {professor_id} deleted successfully")
                return True
        print(f"Professor {professor_id} not found")
        return False

    def update_professor(self, professor_id: str, **kwargs) -> bool:
        """Update professor information"""
        professor = self.search_professor_by_id(professor_id)
        if professor:
            if 'name' in kwargs:
                professor.name = kwargs['name']
            if 'email' in kwargs:
                professor.email = kwargs['email']
            if 'rank' in kwargs:
                professor.rank = kwargs['rank']
            print(f"Professor {professor_id} updated successfully")
            return True
        print(f"Professor {professor_id} not found")
        return False

    def search_professor_by_id(self, professor_id: str) -> Optional[Professor]:
        """Search professor by ID"""
        for professor in self.professors:
            if professor.professor_id == professor_id:
                return professor
        return None

    # ==================== Grade Operations ====================

    def add_student_grade(self, student_id: str, course_id: str, marks: float):
        """Add grade for a student in a course"""
        student = self.search_student_by_id(student_id)
        if not student:
            print(f"Student {student_id} not found")
            return False

        course = self.search_course_by_id(course_id)
        if not course:
            print(f"Course {course_id} not found")
            return False

        student.add_course_grade(course_id, marks)
        print(f"Grade added for student {student_id} in course {course_id}")
        return True

    # ==================== Statistics Operations ====================

    def get_course_statistics(self, course_id: str) -> dict:
        """Calculate statistics for a course"""
        marks_list = []
        for student in self.students:
            if course_id in student.courses:
                marks_list.append(student.courses[course_id]['marks'])

        if not marks_list:
            return {'average': 0, 'median': 0, 'count': 0}

        average = sum(marks_list) / len(marks_list)

        sorted_marks = sorted(marks_list)
        n = len(sorted_marks)
        if n % 2 == 0:
            median = (sorted_marks[n//2 - 1] + sorted_marks[n//2]) / 2
        else:
            median = sorted_marks[n//2]

        return {
            'average': round(average, 2),
            'median': round(median, 2),
            'count': len(marks_list),
            'min': min(marks_list),
            'max': max(marks_list)
        }

    # ==================== Report Operations ====================

    def display_student_report(self, student_id: str):
        """Display complete report for a student"""
        student = self.search_student_by_id(student_id)
        if student:
            student.display_student_info()
            avg = student.get_average_marks()
            print(f"Average Marks: {avg:.2f}")
        else:
            print(f"Student {student_id} not found")

    def display_course_report(self, course_id: str):
        """Display report for a course"""
        course = self.search_course_by_id(course_id)
        if not course:
            print(f"Course {course_id} not found")
            return

        course.display_course_details()
        stats = self.get_course_statistics(course_id)
        print(f"\nCourse Statistics:")
        print(f"  Students Enrolled: {stats['count']}")
        print(f"  Average Marks: {stats['average']}")
        print(f"  Median Marks: {stats['median']}")
        if stats['count'] > 0:
            print(f"  Highest Marks: {stats['max']}")
            print(f"  Lowest Marks: {stats['min']}")

    def display_professor_courses(self, professor_id: str):
        """Display all courses taught by a professor"""
        professor = self.search_professor_by_id(professor_id)
        if not professor:
            print(f"Professor {professor_id} not found")
            return

        professor.display_professor_details()
        print("\nCourses Taught:")
        for course_id in professor.course_ids:
            course = self.search_course_by_id(course_id)
            if course:
                course.display_course_details()

    # ==================== CSV File Operations ====================

    def save_students_to_csv(self, filename: str = "students.csv"):
        """Save all students to CSV file"""
        if not self.students:
            print("No students to save")
            return

        with open(filename, 'w', newline='') as file:
            fieldnames = ['student_id', 'first_name', 'last_name', 'email', 'course_ids', 'grades', 'marks']
            writer = csv.DictWriter(file, fieldnames=fieldnames)
            writer.writeheader()
            for student in self.students:
                writer.writerow(student.to_dict())
        print(f"Students saved to {filename}")

    def load_students_from_csv(self, filename: str = "students.csv"):
        """Load students from CSV file"""
        try:
            with open(filename, 'r') as file:
                reader = csv.DictReader(file)
                for row in reader:
                    student = Student(row['student_id'], row['first_name'],
                                    row['last_name'], row['email'])

                    if row['course_ids']:
                        course_ids = row['course_ids'].split(',')
                        grades = row['grades'].split(',')
                        marks_list = row['marks'].split(',')

                        for cid, grade, mark in zip(course_ids, grades, marks_list):
                            student.add_course_grade(cid, float(mark))

                    self.students.append(student)
            print(f"Students loaded from {filename}")
        except FileNotFoundError:
            print(f"File {filename} not found")

    def save_courses_to_csv(self, filename: str = "courses.csv"):
        """Save all courses to CSV file"""
        if not self.courses:
            print("No courses to save")
            return

        with open(filename, 'w', newline='') as file:
            fieldnames = ['course_id', 'course_name', 'credits', 'description']
            writer = csv.DictWriter(file, fieldnames=fieldnames)
            writer.writeheader()
            for course in self.courses:
                writer.writerow(course.to_dict())
        print(f"Courses saved to {filename}")

    def load_courses_from_csv(self, filename: str = "courses.csv"):
        """Load courses from CSV file"""
        try:
            with open(filename, 'r') as file:
                reader = csv.DictReader(file)
                for row in reader:
                    course = Course(row['course_id'], row['course_name'],
                                  int(row['credits']), row['description'])
                    self.courses.append(course)
            print(f"Courses loaded from {filename}")
        except FileNotFoundError:
            print(f"File {filename} not found")

    def save_professors_to_csv(self, filename: str = "professors.csv"):
        """Save all professors to CSV file"""
        if not self.professors:
            print("No professors to save")
            return

        with open(filename, 'w', newline='') as file:
            fieldnames = ['professor_id', 'name', 'email', 'rank', 'course_ids']
            writer = csv.DictWriter(file, fieldnames=fieldnames)
            writer.writeheader()
            for professor in self.professors:
                writer.writerow(professor.to_dict())
        print(f"Professors saved to {filename}")

    def load_professors_from_csv(self, filename: str = "professors.csv"):
        """Load professors from CSV file"""
        try:
            with open(filename, 'r') as file:
                reader = csv.DictReader(file)
                for row in reader:
                    course_ids = row['course_ids'].split(',') if row['course_ids'] else []
                    professor = Professor(row['professor_id'], row['name'],
                                        row['email'], row['rank'], course_ids)
                    self.professors.append(professor)
            print(f"Professors loaded from {filename}")
        except FileNotFoundError:
            print(f"File {filename} not found")

    def save_users_to_csv(self, filename: str = "login.csv"):
        """Save all users to CSV file"""
        if not self.users:
            print("No users to save")
            return

        with open(filename, 'w', newline='') as file:
            fieldnames = ['email', 'password', 'role']
            writer = csv.DictWriter(file, fieldnames=fieldnames)
            writer.writeheader()
            for user in self.users:
                writer.writerow(user.to_dict())
        print(f"Users saved to {filename}")

    def load_users_from_csv(self, filename: str = "login.csv"):
        """Load users from CSV file"""
        try:
            with open(filename, 'r') as file:
                reader = csv.DictReader(file)
                for row in reader:
                    user = LoginUser.__new__(LoginUser)
                    user.email = row['email']
                    user.password_hash = row['password']
                    user.role = row['role']
                    user.is_logged_in = False
                    self.users.append(user)
            print(f"Users loaded from {filename}")
        except FileNotFoundError:
            print(f"File {filename} not found")

    def save_all_data(self):
        """Save all data to CSV files"""
        self.save_students_to_csv()
        self.save_courses_to_csv()
        self.save_professors_to_csv()
        self.save_users_to_csv()
        print("\nAll data saved successfully!")

    def load_all_data(self):
        """Load all data from CSV files"""
        self.load_students_from_csv()
        self.load_courses_from_csv()
        self.load_professors_from_csv()
        self.load_users_from_csv()
        print("\nAll data loaded successfully!")


# Unit Tests


class TestCheckMyGradeApp(unittest.TestCase):
    """Comprehensive unit tests for CheckMyGrade Application"""

    def setUp(self):
        """Set up test fixtures before each test"""
        self.app = CheckMyGradeApp()

    def test_01_add_student(self):
        """Test adding students to the system"""
        print("\n" + "="*60)
        print("TEST 1: Adding Students")
        print("="*60)

        start_time = time.time()
        student = self.app.add_student("John", "Doe", "john@student.edu")
        end_time = time.time()

        self.assertIsNotNone(student)
        self.assertEqual(student.first_name, "John")
        self.assertEqual(len(self.app.students), 1)

        print(f"✓ Student added successfully")
        print(f"Execution time: {(end_time - start_time)*1000:.4f} milliseconds")

    def test_02_delete_student(self):
        """Test deleting students"""
        print("\n" + "="*60)
        print("TEST 2: Deleting Students")
        print("="*60)

        student = self.app.add_student("Jane", "Smith", "jane@student.edu")
        student_id = student.student_id

        start_time = time.time()
        result = self.app.delete_student(student_id)
        end_time = time.time()

        self.assertTrue(result)
        self.assertEqual(len(self.app.students), 0)

        print(f"✓ Student deleted successfully")
        print(f"Execution time: {(end_time - start_time)*1000:.4f} milliseconds")

    def test_03_update_student(self):
        """Test updating student information"""
        print("\n" + "="*60)
        print("TEST 3: Updating Student Records")
        print("="*60)

        student = self.app.add_student("Bob", "Johnson", "bob@student.edu")

        start_time = time.time()
        result = self.app.update_student(student.student_id, first_name="Robert")
        end_time = time.time()

        self.assertTrue(result)
        self.assertEqual(student.first_name, "Robert")

        print(f"✓ Student updated successfully")
        print(f"Execution time: {(end_time - start_time)*1000:.4f} milliseconds")

    def test_04_add_large_student_dataset(self):
        """Test adding 1000+ student records"""
        print("\n" + "="*60)
        print("TEST 4: Adding 1000+ Student Records")
        print("="*60)

        start_time = time.time()
        for i in range(1000):
            self.app.add_student(f"Student{i}", f"Last{i}", f"student{i}@edu.com")
        end_time = time.time()

        self.assertEqual(len(self.app.students), 1000)

        print(f"✓ 1000 students added successfully")
        print(f"Total execution time: {(end_time - start_time)*1000:.2f} milliseconds")
        print(f"Average time per student: {((end_time - start_time)*1000)/1000:.4f} milliseconds")

    def test_05_search_performance(self):
        """Test search performance with large dataset"""
        print("\n" + "="*60)
        print("TEST 5: Search Performance Test")
        print("="*60)

        # Add 1000 students
        for i in range(1000):
            self.app.add_student(f"Student{i}", f"Last{i}", f"student{i}@edu.com")

        # Search for student in beginning
        start_time = time.time()
        result = self.app.search_student_by_email("student5@edu.com")
        end_time = time.time()
        search_time_start = (end_time - start_time) * 1000

        self.assertIsNotNone(result)
        print(f"✓ Search at beginning: {search_time_start:.4f} milliseconds")

        # Search for student in middle
        start_time = time.time()
        result = self.app.search_student_by_email("student500@edu.com")
        end_time = time.time()
        search_time_mid = (end_time - start_time) * 1000

        self.assertIsNotNone(result)
        print(f"✓ Search in middle: {search_time_mid:.4f} milliseconds")

        # Search for student at end
        start_time = time.time()
        result = self.app.search_student_by_email("student999@edu.com")
        end_time = time.time()
        search_time_end = (end_time - start_time) * 1000

        self.assertIsNotNone(result)
        print(f"✓ Search at end: {search_time_end:.4f} milliseconds")
        print(f"Average search time: {(search_time_start + search_time_mid + search_time_end)/3:.4f} milliseconds")

    def test_06_sort_by_name(self):
        """Test sorting students by name"""
        print("\n" + "="*60)
        print("TEST 6: Sort Students by Name")
        print("="*60)

        # Add students
        self.app.add_student("Zara", "Adams", "zara@edu.com")
        self.app.add_student("Alice", "Brown", "alice@edu.com")
        self.app.add_student("Mike", "Chen", "mike@edu.com")

        start_time = time.time()
        self.app.sort_students_by_name()
        end_time = time.time()

        # Check if sorted correctly (ascending)
        self.assertEqual(self.app.students[0].first_name, "Alice")
        self.assertEqual(self.app.students[1].first_name, "Mike")
        self.assertEqual(self.app.students[2].first_name, "Zara")

        print(f"✓ Students sorted by name (ascending)")
        print(f"Execution time: {(end_time - start_time)*1000:.4f} milliseconds")

        # Test descending sort
        start_time = time.time()
        self.app.sort_students_by_name(reverse=True)
        end_time = time.time()

        self.assertEqual(self.app.students[0].first_name, "Zara")
        print(f"✓ Students sorted by name (descending)")
        print(f"Execution time: {(end_time - start_time)*1000:.4f} milliseconds")

    def test_07_sort_by_marks(self):
        """Test sorting students by marks"""
        print("\n" + "="*60)
        print("TEST 7: Sort Students by Marks")
        print("="*60)

        # Add students with grades
        s1 = self.app.add_student("Alice", "Cooper", "alice@edu.com")
        s2 = self.app.add_student("Bob", "Martin", "bob@edu.com")
        s3 = self.app.add_student("Charlie", "Brown", "charlie@edu.com")

        # Add course first
        self.app.add_course("DATA200", "Data Structures", 3, "DS Course")

        # Add grades
        self.app.add_student_grade(s1.student_id, "DATA200", 85)
        self.app.add_student_grade(s2.student_id, "DATA200", 95)
        self.app.add_student_grade(s3.student_id, "DATA200", 75)

        start_time = time.time()
        self.app.sort_students_by_marks(reverse=True)
        end_time = time.time()

        # Check if sorted correctly (highest to lowest)
        self.assertEqual(self.app.students[0].first_name, "Bob")
        self.assertEqual(self.app.students[1].first_name, "Alice")
        self.assertEqual(self.app.students[2].first_name, "Charlie")

        print(f"✓ Students sorted by marks (highest to lowest)")
        print(f"Execution time: {(end_time - start_time)*1000:.4f} milliseconds")

    def test_08_sort_large_dataset(self):
        """Test sorting performance with 1000+ records"""
        print("\n" + "="*60)
        print("TEST 8: Sort 1000+ Records Performance")
        print("="*60)

        # Add 1000 students
        for i in range(1000):
            self.app.add_student(f"Student{i}", f"Last{999-i}", f"student{i}@edu.com")

        # Sort by name
        start_time = time.time()
        self.app.sort_students_by_name()
        end_time = time.time()

        print(f"✓ 1000 students sorted by name")
        print(f"Execution time: {(end_time - start_time)*1000:.2f} milliseconds")

        # Add grades for sorting by marks
        self.app.add_course("DATA200", "Data Structures", 3)
        for student in self.app.students[:100]:  # Add grades to first 100
            marks = random.uniform(60, 100)
            self.app.add_student_grade(student.student_id, "DATA200", marks)

        start_time = time.time()
        self.app.sort_students_by_marks(reverse=True)
        end_time = time.time()

        print(f"✓ 1000 students sorted by marks")
        print(f"Execution time: {(end_time - start_time)*1000:.2f} milliseconds")

    def test_09_course_operations(self):
        """Test course add/delete/modify operations"""
        print("\n" + "="*60)
        print("TEST 9: Course Operations (Add/Delete/Modify)")
        print("="*60)

        # Test Add
        start_time = time.time()
        course = self.app.add_course("DATA201", "Machine Learning", 3, "ML Course")
        add_time = (time.time() - start_time) * 1000

        self.assertIsNotNone(course)
        self.assertEqual(len(self.app.courses), 1)
        print(f"✓ Course added - Time: {add_time:.4f} ms")

        # Test Modify
        start_time = time.time()
        result = self.app.update_course("DATA201", course_name="Advanced Machine Learning")
        modify_time = (time.time() - start_time) * 1000

        self.assertTrue(result)
        self.assertEqual(course.course_name, "Advanced Machine Learning")
        print(f"✓ Course modified - Time: {modify_time:.4f} ms")

        # Test Delete
        start_time = time.time()
        result = self.app.delete_course("DATA201")
        delete_time = (time.time() - start_time) * 1000

        self.assertTrue(result)
        self.assertEqual(len(self.app.courses), 0)
        print(f"✓ Course deleted - Time: {delete_time:.4f} ms")

    def test_10_professor_operations(self):
        """Test professor add/delete/modify operations"""
        print("\n" + "="*60)
        print("TEST 10: Professor Operations (Add/Delete/Modify)")
        print("="*60)

        # Add course first
        self.app.add_course("DATA200", "Data Structures", 3)

        # Test Add
        start_time = time.time()
        prof = self.app.add_professor("Dr. John Smith", "john@mycsu.edu",
                                      "Senior Professor", ["DATA200"])
        add_time = (time.time() - start_time) * 1000

        self.assertIsNotNone(prof)
        self.assertEqual(len(self.app.professors), 1)
        print(f"✓ Professor added - Time: {add_time:.4f} ms")

        # Test Modify
        start_time = time.time()
        result = self.app.update_professor(prof.professor_id, rank="Distinguished Professor")
        modify_time = (time.time() - start_time) * 1000

        self.assertTrue(result)
        self.assertEqual(prof.rank, "Distinguished Professor")
        print(f"✓ Professor modified - Time: {modify_time:.4f} ms")

        # Test Delete
        start_time = time.time()
        result = self.app.delete_professor(prof.professor_id)
        delete_time = (time.time() - start_time) * 1000

        self.assertTrue(result)
        self.assertEqual(len(self.app.professors), 0)
        print(f"✓ Professor deleted - Time: {delete_time:.4f} ms")

    def test_11_file_operations(self):
        """Test CSV file save and load operations"""
        print("\n" + "="*60)
        print("TEST 11: CSV File Operations (Save/Load)")
        print("="*60)

        # Add sample data
        self.app.add_course("DATA200", "Data Structures", 3, "DS Course")
        student = self.app.add_student("Test", "Student", "test@edu.com")
        self.app.add_professor("Dr. Test", "test@prof.edu", "Professor", ["DATA200"])
        self.app.add_student_grade(student.student_id, "DATA200", 90)

        # Test Save
        start_time = time.time()
        self.app.save_all_data()
        save_time = (time.time() - start_time) * 1000

        print(f"✓ All data saved - Time: {save_time:.4f} ms")

        # Create new app and load
        new_app = CheckMyGradeApp()
        start_time = time.time()
        new_app.load_all_data()
        load_time = (time.time() - start_time) * 1000

        self.assertEqual(len(new_app.students), 1)
        self.assertEqual(len(new_app.courses), 1)
        self.assertEqual(len(new_app.professors), 1)

        print(f"✓ All data loaded - Time: {load_time:.4f} ms")

    def test_12_statistics(self):
        """Test course statistics calculation"""
        print("\n" + "="*60)
        print("TEST 12: Course Statistics (Average/Median)")
        print("="*60)

        # Setup course and students
        self.app.add_course("DATA200", "Data Structures", 3)
        s1 = self.app.add_student("Student1", "Last1", "s1@edu.com")
        s2 = self.app.add_student("Student2", "Last2", "s2@edu.com")
        s3 = self.app.add_student("Student3", "Last3", "s3@edu.com")

        # Add grades
        self.app.add_student_grade(s1.student_id, "DATA200", 80)
        self.app.add_student_grade(s2.student_id, "DATA200", 90)
        self.app.add_student_grade(s3.student_id, "DATA200", 70)

        start_time = time.time()
        stats = self.app.get_course_statistics("DATA200")
        calc_time = (time.time() - start_time) * 1000

        self.assertEqual(stats['average'], 80.0)
        self.assertEqual(stats['median'], 80.0)
        self.assertEqual(stats['count'], 3)

        print(f"✓ Statistics calculated")
        print(f"  Average: {stats['average']}")
        print(f"  Median: {stats['median']}")
        print(f"  Count: {stats['count']}")
        print(f"Execution time: {calc_time:.4f} ms")

    def test_13_password_encryption(self):
        """Test password encryption and verification"""
        print("\n" + "="*60)
        print("TEST 13: Password Encryption and Login")
        print("="*60)

        # Create user
        start_time = time.time()
        user = LoginUser("test@user.com", "Welcome12#_", "student")
        encrypt_time = (time.time() - start_time) * 1000

        print(f"✓ Password encrypted - Time: {encrypt_time:.4f} ms")
        print(f"Original password: Welcome12#_")
        print(f"Encrypted hash: {user.password_hash[:32]}...")

        # Test correct login
        start_time = time.time()
        result = user.login("Welcome12#_")
        login_time = (time.time() - start_time) * 1000

        self.assertTrue(result)
        print(f"✓ Login successful - Time: {login_time:.4f} ms")

        # Test incorrect login
        user2 = LoginUser("test2@user.com", "Password123", "student")
        result = user2.login("WrongPassword")
        self.assertFalse(result)
        print(f"✓ Invalid login rejected correctly")


# Complete Demo with All Features


def run_complete_demo():
    """Run comprehensive demonstration of all features"""
    print("\n")
    print("="*70)
    print(" "*15 + "CheckMyGrade Application")
    print(" "*15 + "Complete Feature Demonstration")
    print("="*70)

    app = CheckMyGradeApp()

    # ========== SECTION 1: Course Management ==========
    print("\n" + "="*70)
    print("SECTION 1: COURSE MANAGEMENT")
    print("="*70)

    print("\n--- Adding Courses ---")
    app.add_course("DATA200", "Data Structures and Algorithms", 3,
                   "Learn fundamental data structures and algorithms")
    app.add_course("DATA201", "Machine Learning Fundamentals", 3,
                   "Introduction to ML concepts and techniques")
    app.add_course("DATA202", "Database Systems", 3,
                   "Relational and NoSQL database design")
    app.add_course("DATA203", "Big Data Analytics", 3,
                   "Processing and analyzing large datasets")

    print(f"\nTotal courses added: {len(app.courses)}")

    # ========== SECTION 2: Professor Management ==========
    print("\n" + "="*70)
    print("SECTION 2: PROFESSOR MANAGEMENT")
    print("="*70)

    print("\n--- Adding Professors ---")
    prof1 = app.add_professor("Dr. Michael Johnson", "michael@mycsu.edu",
                              "Senior Professor", ["DATA200", "DATA201"])
    prof2 = app.add_professor("Dr. Sarah Williams", "sarah@mycsu.edu",
                              "Associate Professor", ["DATA202"])
    prof3 = app.add_professor("Dr. Robert Chen", "robert@mycsu.edu",
                              "Assistant Professor", ["DATA203"])

    print(f"\nTotal professors added: {len(app.professors)}")

    # Display professor details
    print("\n--- Professor Course Details ---")
    app.display_professor_courses(prof1.professor_id)

    # ========== SECTION 3: Student Management ==========
    print("\n" + "="*70)
    print("SECTION 3: STUDENT MANAGEMENT")
    print("="*70)

    print("\n--- Adding Students ---")
    students_data = [
        ("Alice", "Cooper", "alice.cooper@student.edu"),
        ("Bob", "Martin", "bob.martin@student.edu"),
        ("Charlie", "Brown", "charlie.brown@student.edu"),
        ("Diana", "Prince", "diana.prince@student.edu"),
        ("Edward", "Norton", "edward.norton@student.edu"),
        ("Fiona", "Apple", "fiona.apple@student.edu"),
        ("George", "Miller", "george.miller@student.edu"),
        ("Hannah", "Montana", "hannah.montana@student.edu"),
    ]

    added_students = []
    for first, last, email in students_data:
        student = app.add_student(first, last, email)
        added_students.append(student)

    print(f"\nTotal students added: {len(app.students)}")

    # ========== SECTION 4: Grade Management ==========
    print("\n" + "="*70)
    print("SECTION 4: GRADE MANAGEMENT")
    print("="*70)

    print("\n--- Assigning Grades to Students ---")
    # Assign grades for DATA200
    grades_data = [
        (added_students[0].student_id, "DATA200", 95),
        (added_students[1].student_id, "DATA200", 78),
        (added_students[2].student_id, "DATA200", 85),
        (added_students[3].student_id, "DATA200", 92),
        (added_students[4].student_id, "DATA200", 88),
        (added_students[5].student_id, "DATA200", 76),
        (added_students[6].student_id, "DATA200", 90),
        (added_students[7].student_id, "DATA200", 83),
    ]

    for sid, cid, marks in grades_data:
        app.add_student_grade(sid, cid, marks)

    # Assign grades for DATA201
    for i, student in enumerate(added_students[:6]):
        marks = random.randint(70, 100)
        app.add_student_grade(student.student_id, "DATA201", marks)

    print(f"✓ Grades assigned successfully")

    # ========== SECTION 5: Reports ==========
    print("\n" + "="*70)
    print("SECTION 5: STUDENT AND COURSE REPORTS")
    print("="*70)

    print("\n--- Individual Student Report ---")
    app.display_student_report(added_students[0].student_id)

    print("\n--- Course Statistics Report ---")
    app.display_course_report("DATA200")

    # ========== SECTION 6: Search Operations ==========
    print("\n" + "="*70)
    print("SECTION 6: SEARCH OPERATIONS WITH TIMING")
    print("="*70)

    print("\n--- Searching Student by Email ---")
    start_time = time.time()
    result = app.search_student_by_email("alice.cooper@student.edu")
    search_time = (time.time() - start_time) * 1000

    if result:
        print(f"✓ Student Found: {result.first_name} {result.last_name}")
        print(f"  Email: {result.email}")
        print(f"  Student ID: {result.student_id}")
        print(f"Search Time: {search_time:.4f} milliseconds")

    # ========== SECTION 7: Sorting Operations ==========
    print("\n" + "="*70)
    print("SECTION 7: SORTING OPERATIONS WITH TIMING")
    print("="*70)

    print("\n--- Sort Students by Name (Ascending) ---")
    start_time = time.time()
    app.sort_students_by_name()
    sort_time = (time.time() - start_time) * 1000

    print("Sorted List:")
    for i, student in enumerate(app.students[:5], 1):
        print(f"  {i}. {student.first_name} {student.last_name}")
    print(f"Sort Time: {sort_time:.4f} milliseconds")

    print("\n--- Sort Students by Marks (Descending) ---")
    start_time = time.time()
    app.sort_students_by_marks(reverse=True)
    sort_time = (time.time() - start_time) * 1000

    print("Top 5 Students by Average Marks:")
    for i, student in enumerate(app.students[:5], 1):
        avg = student.get_average_marks()
        print(f"  {i}. {student.first_name} {student.last_name}: {avg:.2f}")
    print(f"Sort Time: {sort_time:.4f} milliseconds")

    # ========== SECTION 8: Update Operations ==========
    print("\n" + "="*70)
    print("SECTION 8: UPDATE OPERATIONS")
    print("="*70)

    print("\n--- Updating Student Information ---")
    old_name = added_students[0].first_name
    app.update_student(added_students[0].student_id, first_name="Alicia")
    print(f"✓ Updated: {old_name} -> {added_students[0].first_name}")

    print("\n--- Updating Course Information ---")
    app.update_course("DATA200", description="Advanced data structures with Python implementation")
    print("✓ Course description updated")

    # ========== SECTION 9: Delete Operations ==========
    print("\n" + "="*70)
    print("SECTION 9: DELETE OPERATIONS")
    print("="*70)

    print("\n--- Deleting a Student ---")
    student_to_delete = added_students[-1]
    print(f"Deleting: {student_to_delete.first_name} {student_to_delete.last_name}")
    app.delete_student(student_to_delete.student_id)
    print(f"Remaining students: {len(app.students)}")

    # ========== SECTION 10: User Authentication ==========
    print("\n" + "="*70)
    print("SECTION 10: USER AUTHENTICATION")
    print("="*70)

    print("\n--- Creating User Account ---")
    user = LoginUser("alice.cooper@student.edu", "SecurePass123!", "student")
    print(f"User created: {user.email}")
    print(f"Password encrypted: {user.password_hash[:40]}...")

    print("\n--- Testing Login ---")
    login_result = user.login("SecurePass123!")
    print(f"Login status: {'Success' if login_result else 'Failed'}")

    print("\n--- Testing Password Change ---")
    change_result = user.change_password("SecurePass123!", "NewPassword456!")
    print(f"Password change status: {'Success' if change_result else 'Failed'}")

    # ========== SECTION 11: File Operations ==========
    print("\n" + "="*70)
    print("SECTION 11: CSV FILE OPERATIONS")
    print("="*70)

    print("\n--- Saving Data to CSV Files ---")
    start_time = time.time()
    app.save_all_data()
    save_time = (time.time() - start_time) * 1000
    print(f"Total save time: {save_time:.2f} milliseconds")

    print("\n--- Loading Data from CSV Files ---")
    new_app = CheckMyGradeApp()
    start_time = time.time()
    new_app.load_all_data()
    load_time = (time.time() - start_time) * 1000

    print(f"\nData Loaded:")
    print(f"  Students: {len(new_app.students)}")
    print(f"  Courses: {len(new_app.courses)}")
    print(f"  Professors: {len(new_app.professors)}")
    print(f"Total load time: {load_time:.2f} milliseconds")

    # ========== SECTION 12: Performance Testing ==========
    print("\n" + "="*70)
    print("SECTION 12: LARGE DATASET PERFORMANCE TEST")
    print("="*70)

    print("\n--- Adding 1000 Students ---")
    perf_app = CheckMyGradeApp()
    perf_app.add_course("TEST100", "Test Course", 3)

    start_time = time.time()
    for i in range(1000):
        student = perf_app.add_student(f"TestStudent{i}", f"LastName{i}",
                                       f"test{i}@student.edu")
        marks = random.randint(60, 100)
        perf_app.add_student_grade(student.student_id, "TEST100", marks)
    add_time = (time.time() - start_time) * 1000

    print(f"✓ 1000 students added with grades")
    print(f"Total time: {add_time:.2f} milliseconds")
    print(f"Average time per student: {add_time/1000:.4f} milliseconds")

    print("\n--- Searching in 1000 Records ---")
    start_time = time.time()
    result = perf_app.search_student_by_email("test500@student.edu")
    search_time = (time.time() - start_time) * 1000
    print(f"✓ Search completed in {search_time:.4f} milliseconds")

    print("\n--- Sorting 1000 Records by Name ---")
    start_time = time.time()
    perf_app.sort_students_by_name()
    sort_time = (time.time() - start_time) * 1000
    print(f"✓ Sort completed in {sort_time:.2f} milliseconds")

    print("\n--- Sorting 1000 Records by Marks ---")
    start_time = time.time()
    perf_app.sort_students_by_marks(reverse=True)
    sort_time = (time.time() - start_time) * 1000
    print(f"✓ Sort completed in {sort_time:.2f} milliseconds")

    # ========== FINAL SUMMARY ==========
    print("\n" + "="*70)
    print("DEMONSTRATION COMPLETE")
    print("="*70)
    print("\nAll CSV files have been generated:")
    print("  ✓ students.csv")
    print("  ✓ courses.csv")
    print("  ✓ professors.csv")
    print("  ✓ login.csv")
    print("\nAll functionalities tested successfully!")
    print("="*70)


# Main Execution


if __name__ == "__main__":
    print("Choose an option:")
    print("1. Run Complete Demo")
    print("2. Run Unit Tests")
    print("3. Run Both")

    choice = input("\nEnter your choice (1/2/3): ").strip()

    if choice == "1":
        run_complete_demo()
    elif choice == "2":
        print("\n" + "="*70)
        print(" "*20 + "RUNNING UNIT TESTS")
        print("="*70)
        unittest.main(argv=[''], verbosity=2, exit=False)
    elif choice == "3":
        run_complete_demo()
        print("\n\n")
        print("="*70)
        print(" "*20 + "RUNNING UNIT TESTS")
        print("="*70)
        unittest.main(argv=[''], verbosity=2, exit=False)
    else:
        print("Invalid choice. Running complete demo by default.")
        run_complete_demo()
# Out:
# Choose an option:
# 1. Run Complete Demo
# 2. Run Unit Tests
# 3. Run Both
#
# Enter your choice (1/2/3): 3
#
#
# ======================================================================
#                CheckMyGrade Application
#                Complete Feature Demonstration
# ======================================================================
#
# ======================================================================
# SECTION 1: COURSE MANAGEMENT
# ======================================================================
#
# --- Adding Courses ---
# Course Data Structures and Algorithms added successfully
# Course Machine Learning Fundamentals added successfully
# Course Database Systems added successfully
# Course Big Data Analytics added successfully
#
# Total courses added: 4
#
# ======================================================================
# SECTION 2: PROFESSOR MANAGEMENT
# ======================================================================
#
# --- Adding Professors ---
# Professor Dr. Michael Johnson added successfully with ID: PROF_20251105011938_H1YC
# Professor Dr. Sarah Williams added successfully with ID: PROF_20251105011938_RWLC
# Professor Dr. Robert Chen added successfully with ID: PROF_20251105011938_M49Z
#
# Total professors added: 3
#
# --- Professor Course Details ---
#
# Professor ID: PROF_20251105011938_H1YC
# Name: Dr. Michael Johnson
# Email: michael@mycsu.edu
# Rank: Senior Professor
# Courses: DATA200, DATA201
#
# Courses Taught:
#
# Course ID: DATA200
# Course Name: Data Structures and Algorithms
# Credits: 3
# Description: Learn fundamental data structures and algorithms
#
# Course ID: DATA201
# Course Name: Machine Learning Fundamentals
# Credits: 3
# Description: Introduction to ML concepts and techniques
#
# ======================================================================
# SECTION 3: STUDENT MANAGEMENT
# ======================================================================
#
# --- Adding Students ---
# Student Alice Cooper added successfully with ID: STU_20251105011938_6X7G
# Student Bob Martin added successfully with ID: STU_20251105011938_1T2L
# Student Charlie Brown added successfully with ID: STU_20251105011938_47RU
# Student Diana Prince added successfully with ID: STU_20251105011938_QXT3
# Student Edward Norton added successfully with ID: STU_20251105011938_ZJFJ
# Student Fiona Apple added successfully with ID: STU_20251105011938_9LLJ
# Student George Miller added successfully with ID: STU_20251105011938_K2ZX
# Student Hannah Montana added successfully with ID: STU_20251105011938_VMWE
#
# Total students added: 8
#
# ======================================================================
# SECTION 4: GRADE MANAGEMENT
# ======================================================================
#
# --- Assigning Grades to Students ---
# Grade added for student STU_20251105011938_6X7G in course DATA200
# Grade added for student STU_20251105011938_1T2L in course DATA200
# Grade added for student STU_20251105011938_47RU in course DATA200
# Grade added for student STU_20251105011938_QXT3 in course DATA200
# Grade added for student STU_20251105011938_ZJFJ in course DATA200
# Grade added for student STU_20251105011938_9LLJ in course DATA200
# Grade added for student STU_20251105011938_K2ZX in course DATA200
# Grade added for student STU_20251105011938_VMWE in course DATA200
# Grade added for student STU_20251105011938_6X7G in course DATA201
# Grade added for student STU_20251105011938_1T2L in course DATA201
# Grade added for student STU_20251105011938_47RU in course DATA201
# Grade added for student STU_20251105011938_QXT3 in course DATA201
# Grade added for student STU_20251105011938_ZJFJ in course DATA201
# Grade added for student STU_20251105011938_9LLJ in course DATA201
# ✓ Grades assigned successfully
#
# ======================================================================
# SECTION 5: STUDENT AND COURSE REPORTS
# ======================================================================
#
# --- Individual Student Report ---
#
# Student ID: STU_20251105011938_6X7G
# Name: Alice Cooper
# Email: alice.cooper@student.edu
# Enrolled Courses:
#   DATA200: Marks=95, Grade=A
#   DATA201: Marks=84, Grade=B
# Average Marks: 89.50
#
# --- Course Statistics Report ---
#
# Course ID: DATA200
# Course Name: Data Structures and Algorithms
# Credits: 3
# Description: Learn fundamental data structures and algorithms
#
# Course Statistics:
#   Students Enrolled: 8
#   Average Marks: 85.88
#   Median Marks: 86.5
#   Highest Marks: 95
#   Lowest Marks: 76
#
# ======================================================================
# SECTION 6: SEARCH OPERATIONS WITH TIMING
# ======================================================================
#
# --- Searching Student by Email ---
# ✓ Student Found: Alice Cooper
#   Email: alice.cooper@student.edu
#   Student ID: STU_20251105011938_6X7G
# Search Time: 0.0017 milliseconds
#
# ======================================================================
# SECTION 7: SORTING OPERATIONS WITH TIMING
# ======================================================================
#
# --- Sort Students by Name (Ascending) ---
# Sorted List:
#   1. Alice Cooper
#   2. Bob Martin
#   3. Charlie Brown
#   4. Diana Prince
#   5. Edward Norton
# Sort Time: 0.0205 milliseconds
#
# --- Sort Students by Marks (Descending) ---
# Top 5 Students by Average Marks:
#   1. Fiona Apple: 73.50
#   2. Hannah Montana: 83.00
#   3. Charlie Brown: 85.50
#   4. Bob Martin: 86.50
#   5. Diana Prince: 87.00
# Sort Time: 0.0448 milliseconds
#
# ======================================================================
# SECTION 8: UPDATE OPERATIONS
# ======================================================================
#
# --- Updating Student Information ---
# Student STU_20251105011938_6X7G updated successfully
# ✓ Updated: Alice -> Alicia
#
# --- Updating Course Information ---
# Course DATA200 updated successfully
# ✓ Course description updated
#
# ======================================================================
# SECTION 9: DELETE OPERATIONS
# ======================================================================
#
# --- Deleting a Student ---
# Deleting: Hannah Montana
# Student STU_20251105011938_VMWE deleted successfully
# Remaining students: 7
#
# ======================================================================
# SECTION 10: USER AUTHENTICATION
# ======================================================================
#
# --- Creating User Account ---
# User created: alice.cooper@student.edu
# Password encrypted: 6faba6e4ed724c5b54fad19eca98923e2198cdbb...
#
# --- Testing Login ---
# Login successful! Welcome alice.cooper@student.edu
# Login status: Success
#
# --- Testing Password Change ---
# Password changed successfully
# Password change status: Success
#
# ======================================================================
# SECTION 11: CSV FILE OPERATIONS
# ======================================================================
#
# --- Saving Data to CSV Files ---
# Students saved to students.csv
# Courses saved to courses.csv
# Professors saved to professors.csv
# No users to save
#
# All data saved successfully!
# Total save time: 0.85 milliseconds
#
# --- Loading Data from CSV Files ---
# Students loaded from students.csv
# Courses loaded from courses.csv
# Professors loaded from professors.csv
# File login.csv not found
#
# All data loaded successfully!
#
# Data Loaded:
#   Students: 7
#   Courses: 4
#   Professors: 3
# Total load time: 0.55 milliseconds
#
# ======================================================================
# SECTION 12: LARGE DATASET PERFORMANCE TEST
# ======================================================================
#
# --- Adding 1000 Students ---
# Course Test Course added successfully
# Student TestStudent0 LastName0 added successfully with ID: STU_20251105011938_RPC5
# Grade added for student STU_20251105011938_RPC5 in course TEST100
# Student TestStudent1 LastName1 added successfully with ID: STU_20251105011938_JFS3
# Grade added for student STU_20251105011938_JFS3 in course TEST100
# Student TestStudent2 LastName2 added successfully with ID: STU_20251105011938_PMKC
# Grade added for student STU_20251105011938_PMKC in course TEST100
# Student TestStudent3 LastName3 added successfully with ID: STU_20251105011938_2SA1
# Grade added for student STU_20251105011938_2SA1 in course TEST100
# Student TestStudent4 LastName4 added successfully with ID: STU_20251105011938_2YRV
# Grade added for student STU_20251105011938_2YRV in course TEST100
# Student TestStudent5 LastName5 added successfully with ID: STU_20251105011938_2B6I
# Grade added for student STU_20251105011938_2B6I in course TEST100
# Student TestStudent6 LastName6 added successfully with ID: STU_20251105011938_JQ1F
# Grade added for student STU_20251105011938_JQ1F in course TEST100
# Student TestStudent7 LastName7 added successfully with ID: STU_20251105011938_XASQ
# Grade added for student STU_20251105011938_XASQ in course TEST100
# Student TestStudent8 LastName8 added successfully with ID: STU_20251105011938_I9J1
# Grade added for student STU_20251105011938_I9J1 in course TEST100
# Student TestStudent9 LastName9 added successfully with ID: STU_20251105011938_QU5E
# Grade added for student STU_20251105011938_QU5E in course TEST100
# Student TestStudent10 LastName10 added successfully with ID: STU_20251105011938_F1LU
# Grade added for student STU_20251105011938_F1LU in course TEST100
# Student TestStudent11 LastName11 added successfully with ID: STU_20251105011938_VATH
# Grade added for student STU_20251105011938_VATH in course TEST100
# Student TestStudent12 LastName12 added successfully with ID: STU_20251105011938_N9ZM
# Grade added for student STU_20251105011938_N9ZM in course TEST100
# Student TestStudent13 LastName13 added successfully with ID: STU_20251105011938_3XHP
# Grade added for student STU_20251105011938_3XHP in course TEST100
# Student TestStudent14 LastName14 added successfully with ID: STU_20251105011938_OT96
# Grade added for student STU_20251105011938_OT96 in course TEST100
# Student TestStudent15 LastName15 added successfully with ID: STU_20251105011938_MCPF
# Grade added for student STU_20251105011938_MCPF in course TEST100
# Student TestStudent16 LastName16 added successfully with ID: STU_20251105011938_3BCL
# Grade added for student STU_20251105011938_3BCL in course TEST100
# Student TestStudent17 LastName17 added successfully with ID: STU_20251105011938_GW8L
# Grade added for student STU_20251105011938_GW8L in course TEST100
# Student TestStudent18 LastName18 added successfully with ID: STU_20251105011938_ECSX
# Grade added for student STU_20251105011938_ECSX in course TEST100
# Student TestStudent19 LastName19 added successfully with ID: STU_20251105011938_741J
# Grade added for student STU_20251105011938_741J in course TEST100
# Student TestStudent20 LastName20 added successfully with ID: STU_20251105011938_CLBG
# Grade added for student STU_20251105011938_CLBG in course TEST100
# Student TestStudent21 LastName21 added successfully with ID: STU_20251105011938_21ZL
# Grade added for student STU_20251105011938_21ZL in course TEST100
# Student TestStudent22 LastName22 added successfully with ID: STU_20251105011938_VQTD
# Grade added for student STU_20251105011938_VQTD in course TEST100
# Student TestStudent23 LastName23 added successfully with ID: STU_20251105011938_CPCX
# Grade added for student STU_20251105011938_CPCX in course TEST100
# Student TestStudent24 LastName24 added successfully with ID: STU_20251105011938_QY7T
# Grade added for student STU_20251105011938_QY7T in course TEST100
# Student TestStudent25 LastName25 added successfully with ID: STU_20251105011938_4GVX
# Grade added for student STU_20251105011938_4GVX in course TEST100
# Student TestStudent26 LastName26 added successfully with ID: STU_20251105011938_AX1S
# Grade added for student STU_20251105011938_AX1S in course TEST100
# Student TestStudent27 LastName27 added successfully with ID: STU_20251105011938_XJNW
# Grade added for student STU_20251105011938_XJNW in course TEST100
# Student TestStudent28 LastName28 added successfully with ID: STU_20251105011938_JR2Q
# Grade added for student STU_20251105011938_JR2Q in course TEST100
# Student TestStudent29 LastName29 added successfully with ID: STU_20251105011938_PAUB
# Grade added for student STU_20251105011938_PAUB in course TEST100
# Student TestStudent30 LastName30 added successfully with ID: STU_20251105011938_8CJV
# Grade added for student STU_20251105011938_8CJV in course TEST100
# Student TestStudent31 LastName31 added successfully with ID: STU_20251105011938_2S77
# Grade added for student STU_20251105011938_2S77 in course TEST100
# Student TestStudent32 LastName32 added successfully with ID: STU_20251105011938_QMJ1
# Grade added for student STU_20251105011938_QMJ1 in course TEST100
# Student TestStudent33 LastName33 added successfully with ID: STU_20251105011938_Q61O
# Grade added for student STU_20251105011938_Q61O in course TEST100
# Student TestStudent34 LastName34 added successfully with ID: STU_20251105011938_XS7V
# Grade added for student STU_20251105011938_XS7V in course TEST100
# Student TestStudent35 LastName35 added successfully with ID: STU_20251105011938_NACQ
# Grade added for student STU_20251105011938_NACQ in course TEST100
# Student TestStudent36 LastName36 added successfully with ID: STU_20251105011938_0CI8
# Grade added for student STU_20251105011938_0CI8 in course TEST100
# Student TestStudent37 LastName37 added successfully with ID: STU_20251105011938_XMX4
# Grade added for student STU_20251105011938_XMX4 in course TEST100
# Student TestStudent38 LastName38 added successfully with ID: STU_20251105011938_JQPT
# Grade added for student STU_20251105011938_JQPT in course TEST100
# Student TestStudent39 LastName39 added successfully with ID: STU_20251105011938_JH08
# Grade added for student STU_20251105011938_JH08 in course TEST100
# Student TestStudent40 LastName40 added successfully with ID: STU_20251105011938_S14O
# Grade added for student STU_20251105011938_S14O in course TEST100
# Student TestStudent41 LastName41 added successfully with ID: STU_20251105011938_GIXM
# Grade added for student STU_20251105011938_GIXM in course TEST100
# Student TestStudent42 LastName42 added successfully with ID: STU_20251105011938_HO7E
# Grade added for student STU_20251105011938_HO7E in course TEST100
# Student TestStudent43 LastName43 added successfully with ID: STU_20251105011938_CR2R
# Grade added for student STU_20251105011938_CR2R in course TEST100
# Student TestStudent44 LastName44 added successfully with ID: STU_20251105011938_ETL5
# Grade added for student STU_20251105011938_ETL5 in course TEST100
# Student TestStudent45 LastName45 added successfully with ID: STU_20251105011938_NV9D
# Grade added for student STU_20251105011938_NV9D in course TEST100
# Student TestStudent46 LastName46 added successfully with ID: STU_20251105011938_NSN1
# Grade added for student STU_20251105011938_NSN1 in course TEST100
# Student TestStudent47 LastName47 added successfully with ID: STU_20251105011938_URFV
# Grade added for student STU_20251105011938_URFV in course TEST100
# Student TestStudent48 LastName48 added successfully with ID: STU_20251105011938_YWCZ
# Grade added for student STU_20251105011938_YWCZ in course TEST100
# Student TestStudent49 LastName49 added successfully with ID: STU_20251105011938_QBXP
# Grade added for student STU_20251105011938_QBXP in course TEST100
# Student TestStudent50 LastName50 added successfully with ID: STU_20251105011938_MTNK
# Grade added for student STU_20251105011938_MTNK in course TEST100
# Student TestStudent51 LastName51 added successfully with ID: STU_20251105011938_4BW2
# Grade added for student STU_20251105011938_4BW2 in course TEST100
# Student TestStudent52 LastName52 added successfully with ID: STU_20251105011938_H2Z9
# Grade added for student STU_20251105011938_H2Z9 in course TEST100
# Student TestStudent53 LastName53 added successfully with ID: STU_20251105011938_CYBH
# Grade added for student STU_20251105011938_CYBH in course TEST100
# Student TestStudent54 LastName54 added successfully with ID: STU_20251105011938_0SQH
# Grade added for student STU_20251105011938_0SQH in course TEST100
# Student TestStudent55 LastName55 added successfully with ID: STU_20251105011938_6BL7
# Grade added for student STU_20251105011938_6BL7 in course TEST100
# Student TestStudent56 LastName56 added successfully with ID: STU_20251105011938_PV7Y
# Grade added for student STU_20251105011938_PV7Y in course TEST100
# Student TestStudent57 LastName57 added successfully with ID: STU_20251105011938_DV0L
# Grade added for student STU_20251105011938_DV0L in course TEST100
# Student TestStudent58 LastName58 added successfully with ID: STU_20251105011938_4QIA
# Grade added for student STU_20251105011938_4QIA in course TEST100
# Student TestStudent59 LastName59 added successfully with ID: STU_20251105011938_QMOV
# Grade added for student STU_20251105011938_QMOV in course TEST100
# Student TestStudent60 LastName60 added successfully with ID: STU_20251105011938_TG0I
# Grade added for student STU_20251105011938_TG0I in course TEST100
# Student TestStudent61 LastName61 added successfully with ID: STU_20251105011938_JAS6
# Grade added for student STU_20251105011938_JAS6 in course TEST100
# Student TestStudent62 LastName62 added successfully with ID: STU_20251105011938_XOKJ
# Grade added for student STU_20251105011938_XOKJ in course TEST100
# Student TestStudent63 LastName63 added successfully with ID: STU_20251105011938_V02F
# Grade added for student STU_20251105011938_V02F in course TEST100
# Student TestStudent64 LastName64 added successfully with ID: STU_20251105011938_05T6
# Grade added for student STU_20251105011938_05T6 in course TEST100
# Student TestStudent65 LastName65 added successfully with ID: STU_20251105011938_7G3L
# Grade added for student STU_20251105011938_7G3L in course TEST100
# Student TestStudent66 LastName66 added successfully with ID: STU_20251105011938_U8FG
# Grade added for student STU_20251105011938_U8FG in course TEST100
# Student TestStudent67 LastName67 added successfully with ID: STU_20251105011938_HUWV
# Grade added for student STU_20251105011938_HUWV in course TEST100
# Student TestStudent68 LastName68 added successfully with ID: STU_20251105011938_I47Y
# Grade added for student STU_20251105011938_I47Y in course TEST100
# Student TestStudent69 LastName69 added successfully with ID: STU_20251105011938_DKLT
# Grade added for student STU_20251105011938_DKLT in course TEST100
# Student TestStudent70 LastName70 added successfully with ID: STU_20251105011938_3M82
# Grade added for student STU_20251105011938_3M82 in course TEST100
# Student TestStudent71 LastName71 added successfully with ID: STU_20251105011938_XN34
# Grade added for student STU_20251105011938_XN34 in course TEST100
# Student TestStudent72 LastName72 added successfully with ID: STU_20251105011938_GY73
# Grade added for student STU_20251105011938_GY73 in course TEST100
# Student TestStudent73 LastName73 added successfully with ID: STU_20251105011938_CH7H
# Grade added for student STU_20251105011938_CH7H in course TEST100
# Student TestStudent74 LastName74 added successfully with ID: STU_20251105011938_QP1G
# Grade added for student STU_20251105011938_QP1G in course TEST100
# Student TestStudent75 LastName75 added successfully with ID: STU_20251105011938_YBM1
# Grade added for student STU_20251105011938_YBM1 in course TEST100
# Student TestStudent76 LastName76 added successfully with ID: STU_20251105011938_HWOB
# Grade added for student STU_20251105011938_HWOB in course TEST100
# Student TestStudent77 LastName77 added successfully with ID: STU_20251105011938_3BOJ
# Grade added for student STU_20251105011938_3BOJ in course TEST100
# Student TestStudent78 LastName78 added successfully with ID: STU_20251105011938_B9UB
# Grade added for student STU_20251105011938_B9UB in course TEST100
# Student TestStudent79 LastName79 added successfully with ID: STU_20251105011938_PH99
# Grade added for student STU_20251105011938_PH99 in course TEST100
# Student TestStudent80 LastName80 added successfully with ID: STU_20251105011938_A8BC
# Grade added for student STU_20251105011938_A8BC in course TEST100
# Student TestStudent81 LastName81 added successfully with ID: STU_20251105011938_HK9X
# Grade added for student STU_20251105011938_HK9X in course TEST100
# Student TestStudent82 LastName82 added successfully with ID: STU_20251105011938_2UMA
# Grade added for student STU_20251105011938_2UMA in course TEST100
# Student TestStudent83 LastName83 added successfully with ID: STU_20251105011938_53KF
# Grade added for student STU_20251105011938_53KF in course TEST100
# Student TestStudent84 LastName84 added successfully with ID: STU_20251105011938_K7L8
# Grade added for student STU_20251105011938_K7L8 in course TEST100
# Student TestStudent85 LastName85 added successfully with ID: STU_20251105011938_T51T
# Grade added for student STU_20251105011938_T51T in course TEST100
# Student TestStudent86 LastName86 added successfully with ID: STU_20251105011938_JCON
# Grade added for student STU_20251105011938_JCON in course TEST100
# Student TestStudent87 LastName87 added successfully with ID: STU_20251105011938_6H9B
# Grade added for student STU_20251105011938_6H9B in course TEST100
# Student TestStudent88 LastName88 added successfully with ID: STU_20251105011938_3GYQ
# Grade added for student STU_20251105011938_3GYQ in course TEST100
# Student TestStudent89 LastName89 added successfully with ID: STU_20251105011938_VCDN
# Grade added for student STU_20251105011938_VCDN in course TEST100
# Student TestStudent90 LastName90 added successfully with ID: STU_20251105011938_J3MP
# Grade added for student STU_20251105011938_J3MP in course TEST100
# Student TestStudent91 LastName91 added successfully with ID: STU_20251105011938_EDS4
# Grade added for student STU_20251105011938_EDS4 in course TEST100
# Student TestStudent92 LastName92 added successfully with ID: STU_20251105011938_OK1Y
# Grade added for student STU_20251105011938_OK1Y in course TEST100
# Student TestStudent93 LastName93 added successfully with ID: STU_20251105011938_B8DS
# Grade added for student STU_20251105011938_B8DS in course TEST100
# Student TestStudent94 LastName94 added successfully with ID: STU_20251105011938_R334
# Grade added for student STU_20251105011938_R334 in course TEST100
# Student TestStudent95 LastName95 added successfully with ID: STU_20251105011938_LXUA
# Grade added for student STU_20251105011938_LXUA in course TEST100
# Student TestStudent96 LastName96 added successfully with ID: STU_20251105011938_4895
# Grade added for student STU_20251105011938_4895 in course TEST100
# Student TestStudent97 LastName97 added successfully with ID: STU_20251105011938_0CTE
# Grade added for student STU_20251105011938_0CTE in course TEST100
# Student TestStudent98 LastName98 added successfully with ID: STU_20251105011938_KWFX
# Grade added for student STU_20251105011938_KWFX in course TEST100
# Student TestStudent99 LastName99 added successfully with ID: STU_20251105011938_7QAO
# Grade added for student STU_20251105011938_7QAO in course TEST100
# Student TestStudent100 LastName100 added successfully with ID: STU_20251105011938_KUC3
# Grade added for student STU_20251105011938_KUC3 in course TEST100
# Student TestStudent101 LastName101 added successfully with ID: STU_20251105011938_5OHV
# Grade added for student STU_20251105011938_5OHV in course TEST100
# Student TestStudent102 LastName102 added successfully with ID: STU_20251105011938_MEJV
# Grade added for student STU_20251105011938_MEJV in course TEST100
# Student TestStudent103 LastName103 added successfully with ID: STU_20251105011938_47F9
# Grade added for student STU_20251105011938_47F9 in course TEST100
# Student TestStudent104 LastName104 added successfully with ID: STU_20251105011938_WPA4
# Grade added for student STU_20251105011938_WPA4 in course TEST100
# Student TestStudent105 LastName105 added successfully with ID: STU_20251105011938_B9I9
# Grade added for student STU_20251105011938_B9I9 in course TEST100
# Student TestStudent106 LastName106 added successfully with ID: STU_20251105011938_VKYZ
# Grade added for student STU_20251105011938_VKYZ in course TEST100
# Student TestStudent107 LastName107 added successfully with ID: STU_20251105011938_CJKA
# Grade added for student STU_20251105011938_CJKA in course TEST100
# Student TestStudent108 LastName108 added successfully with ID: STU_20251105011938_3LG9
# Grade added for student STU_20251105011938_3LG9 in course TEST100
# Student TestStudent109 LastName109 added successfully with ID: STU_20251105011938_7M59
# Grade added for student STU_20251105011938_7M59 in course TEST100
# Student TestStudent110 LastName110 added successfully with ID: STU_20251105011938_N4OD
# Grade added for student STU_20251105011938_N4OD in course TEST100
# Student TestStudent111 LastName111 added successfully with ID: STU_20251105011938_J0MP
# Grade added for student STU_20251105011938_J0MP in course TEST100
# Student TestStudent112 LastName112 added successfully with ID: STU_20251105011938_O9QW
# Grade added for student STU_20251105011938_O9QW in course TEST100
# Student TestStudent113 LastName113 added successfully with ID: STU_20251105011938_CA54
# Grade added for student STU_20251105011938_CA54 in course TEST100
# Student TestStudent114 LastName114 added successfully with ID: STU_20251105011938_CNIN
# Grade added for student STU_20251105011938_CNIN in course TEST100
# Student TestStudent115 LastName115 added successfully with ID: STU_20251105011938_6HKJ
# Grade added for student STU_20251105011938_6HKJ in course TEST100
# Student TestStudent116 LastName116 added successfully with ID: STU_20251105011938_GIRX
# Grade added for student STU_20251105011938_GIRX in course TEST100
# Student TestStudent117 LastName117 added successfully with ID: STU_20251105011938_Y0TN
# Grade added for student STU_20251105011938_Y0TN in course TEST100
# Student TestStudent118 LastName118 added successfully with ID: STU_20251105011938_8OP7
# Grade added for student STU_20251105011938_8OP7 in course TEST100
# Student TestStudent119 LastName119 added successfully with ID: STU_20251105011938_QG1M
# Grade added for student STU_20251105011938_QG1M in course TEST100
# Student TestStudent120 LastName120 added successfully with ID: STU_20251105011938_MAM0
# Grade added for student STU_20251105011938_MAM0 in course TEST100
# Student TestStudent121 LastName121 added successfully with ID: STU_20251105011938_CKEZ
# Grade added for student STU_20251105011938_CKEZ in course TEST100
# Student TestStudent122 LastName122 added successfully with ID: STU_20251105011938_S4IF
# Grade added for student STU_20251105011938_S4IF in course TEST100
# Student TestStudent123 LastName123 added successfully with ID: STU_20251105011938_B4L4
# Grade added for student STU_20251105011938_B4L4 in course TEST100
# Student TestStudent124 LastName124 added successfully with ID: STU_20251105011938_V0GQ
# Grade added for student STU_20251105011938_V0GQ in course TEST100
# Student TestStudent125 LastName125 added successfully with ID: STU_20251105011938_699O
# Grade added for student STU_20251105011938_699O in course TEST100
# Student TestStudent126 LastName126 added successfully with ID: STU_20251105011938_QE2E
# Grade added for student STU_20251105011938_QE2E in course TEST100
# Student TestStudent127 LastName127 added successfully with ID: STU_20251105011938_ZITV
# Grade added for student STU_20251105011938_ZITV in course TEST100
# Student TestStudent128 LastName128 added successfully with ID: STU_20251105011938_EEVV
# Grade added for student STU_20251105011938_EEVV in course TEST100
# Student TestStudent129 LastName129 added successfully with ID: STU_20251105011938_7PLO
# Grade added for student STU_20251105011938_7PLO in course TEST100
# Student TestStudent130 LastName130 added successfully with ID: STU_20251105011938_7I2F
# Grade added for student STU_20251105011938_7I2F in course TEST100
# Student TestStudent131 LastName131 added successfully with ID: STU_20251105011938_HDGP
# Grade added for student STU_20251105011938_HDGP in course TEST100
# Student TestStudent132 LastName132 added successfully with ID: STU_20251105011938_MNY2
# Grade added for student STU_20251105011938_MNY2 in course TEST100
# Student TestStudent133 LastName133 added successfully with ID: STU_20251105011938_94WA
# Grade added for student STU_20251105011938_94WA in course TEST100
# Student TestStudent134 LastName134 added successfully with ID: STU_20251105011938_JMM9
# Grade added for student STU_20251105011938_JMM9 in course TEST100
# Student TestStudent135 LastName135 added successfully with ID: STU_20251105011938_XV1Q
# Grade added for student STU_20251105011938_XV1Q in course TEST100
# Student TestStudent136 LastName136 added successfully with ID: STU_20251105011938_35GA
# Grade added for student STU_20251105011938_35GA in course TEST100
# Student TestStudent137 LastName137 added successfully with ID: STU_20251105011938_C0IA
# Grade added for student STU_20251105011938_C0IA in course TEST100
# Student TestStudent138 LastName138 added successfully with ID: STU_20251105011938_HALI
# Grade added for student STU_20251105011938_HALI in course TEST100
# Student TestStudent139 LastName139 added successfully with ID: STU_20251105011938_4TJX
# Grade added for student STU_20251105011938_4TJX in course TEST100
# Student TestStudent140 LastName140 added successfully with ID: STU_20251105011938_XBMG
# Grade added for student STU_20251105011938_XBMG in course TEST100
# Student TestStudent141 LastName141 added successfully with ID: STU_20251105011938_JVQO
# Grade added for student STU_20251105011938_JVQO in course TEST100
# Student TestStudent142 LastName142 added successfully with ID: STU_20251105011938_3C46
# Grade added for student STU_20251105011938_3C46 in course TEST100
# Student TestStudent143 LastName143 added successfully with ID: STU_20251105011938_XC3O
# Grade added for student STU_20251105011938_XC3O in course TEST100
# Student TestStudent144 LastName144 added successfully with ID: STU_20251105011938_NOQG
# Grade added for student STU_20251105011938_NOQG in course TEST100
# Student TestStudent145 LastName145 added successfully with ID: STU_20251105011938_SIRR
# Grade added for student STU_20251105011938_SIRR in course TEST100
# Student TestStudent146 LastName146 added successfully with ID: STU_20251105011938_RHYL
# Grade added for student STU_20251105011938_RHYL in course TEST100
# Student TestStudent147 LastName147 added successfully with ID: STU_20251105011938_IPJT
# Grade added for student STU_20251105011938_IPJT in course TEST100
# Student TestStudent148 LastName148 added successfully with ID: STU_20251105011938_60FS
# Grade added for student STU_20251105011938_60FS in course TEST100
# Student TestStudent149 LastName149 added successfully with ID: STU_20251105011938_QZSP
# Grade added for student STU_20251105011938_QZSP in course TEST100
# Student TestStudent150 LastName150 added successfully with ID: STU_20251105011938_9I51
# Grade added for student STU_20251105011938_9I51 in course TEST100
# Student TestStudent151 LastName151 added successfully with ID: STU_20251105011938_VVH4
# Grade added for student STU_20251105011938_VVH4 in course TEST100
# Student TestStudent152 LastName152 added successfully with ID: STU_20251105011938_U3GW
# Grade added for student STU_20251105011938_U3GW in course TEST100
# Student TestStudent153 LastName153 added successfully with ID: STU_20251105011938_MESV
# Grade added for student STU_20251105011938_MESV in course TEST100
# Student TestStudent154 LastName154 added successfully with ID: STU_20251105011938_DYPF
# Grade added for student STU_20251105011938_DYPF in course TEST100
# Student TestStudent155 LastName155 added successfully with ID: STU_20251105011938_MYQL
# Grade added for student STU_20251105011938_MYQL in course TEST100
# Student TestStudent156 LastName156 added successfully with ID: STU_20251105011938_S54F
# Grade added for student STU_20251105011938_S54F in course TEST100
# Student TestStudent157 LastName157 added successfully with ID: STU_20251105011938_PEPW
# Grade added for student STU_20251105011938_PEPW in course TEST100
# Student TestStudent158 LastName158 added successfully with ID: STU_20251105011938_XW1G
# Grade added for student STU_20251105011938_XW1G in course TEST100
# Student TestStudent159 LastName159 added successfully with ID: STU_20251105011938_IT6S
# Grade added for student STU_20251105011938_IT6S in course TEST100
# Student TestStudent160 LastName160 added successfully with ID: STU_20251105011938_RUX3
# Grade added for student STU_20251105011938_RUX3 in course TEST100
# Student TestStudent161 LastName161 added successfully with ID: STU_20251105011938_77EG
# Grade added for student STU_20251105011938_77EG in course TEST100
# Student TestStudent162 LastName162 added successfully with ID: STU_20251105011938_CRKT
# Grade added for student STU_20251105011938_CRKT in course TEST100
# Student TestStudent163 LastName163 added successfully with ID: STU_20251105011938_0AD2
# Grade added for student STU_20251105011938_0AD2 in course TEST100
# Student TestStudent164 LastName164 added successfully with ID: STU_20251105011938_K6YU
# Grade added for student STU_20251105011938_K6YU in course TEST100
# Student TestStudent165 LastName165 added successfully with ID: STU_20251105011938_AGOS
# Grade added for student STU_20251105011938_AGOS in course TEST100
# Student TestStudent166 LastName166 added successfully with ID: STU_20251105011938_1BH7
# Grade added for student STU_20251105011938_1BH7 in course TEST100
# Student TestStudent167 LastName167 added successfully with ID: STU_20251105011938_XYAP
# Grade added for student STU_20251105011938_XYAP in course TEST100
# Student TestStudent168 LastName168 added successfully with ID: STU_20251105011938_OV5Q
# Grade added for student STU_20251105011938_OV5Q in course TEST100
# Student TestStudent169 LastName169 added successfully with ID: STU_20251105011938_X44K
# Grade added for student STU_20251105011938_X44K in course TEST100
# Student TestStudent170 LastName170 added successfully with ID: STU_20251105011938_VY0D
# Grade added for student STU_20251105011938_VY0D in course TEST100
# Student TestStudent171 LastName171 added successfully with ID: STU_20251105011938_8EQZ
# Grade added for student STU_20251105011938_8EQZ in course TEST100
# Student TestStudent172 LastName172 added successfully with ID: STU_20251105011938_MI9Y
# Grade added for student STU_20251105011938_MI9Y in course TEST100
# Student TestStudent173 LastName173 added successfully with ID: STU_20251105011938_PAPP
# Grade added for student STU_20251105011938_PAPP in course TEST100
# Student TestStudent174 LastName174 added successfully with ID: STU_20251105011938_SGZJ
# Grade added for student STU_20251105011938_SGZJ in course TEST100
# Student TestStudent175 LastName175 added successfully with ID: STU_20251105011938_99NR
# Grade added for student STU_20251105011938_99NR in course TEST100
# Student TestStudent176 LastName176 added successfully with ID: STU_20251105011938_5KJF
# Grade added for student STU_20251105011938_5KJF in course TEST100
# Student TestStudent177 LastName177 added successfully with ID: STU_20251105011938_528K
# Grade added for student STU_20251105011938_528K in course TEST100
# Student TestStudent178 LastName178 added successfully with ID: STU_20251105011938_9L6P
# Grade added for student STU_20251105011938_9L6P in course TEST100
# Student TestStudent179 LastName179 added successfully with ID: STU_20251105011938_CI35
# Grade added for student STU_20251105011938_CI35 in course TEST100
# Student TestStudent180 LastName180 added successfully with ID: STU_20251105011938_Z2N6
# Grade added for student STU_20251105011938_Z2N6 in course TEST100
# Student TestStudent181 LastName181 added successfully with ID: STU_20251105011938_5IUI
# Grade added for student STU_20251105011938_5IUI in course TEST100
# Student TestStudent182 LastName182 added successfully with ID: STU_20251105011938_0X5P
# Grade added for student STU_20251105011938_0X5P in course TEST100
# Student TestStudent183 LastName183 added successfully with ID: STU_20251105011938_HRV7
# Grade added for student STU_20251105011938_HRV7 in course TEST100
# Student TestStudent184 LastName184 added successfully with ID: STU_20251105011938_1EYB
# Grade added for student STU_20251105011938_1EYB in course TEST100
# Student TestStudent185 LastName185 added successfully with ID: STU_20251105011938_MY0R
# Grade added for student STU_20251105011938_MY0R in course TEST100
# Student TestStudent186 LastName186 added successfully with ID: STU_20251105011938_9B3M
# Grade added for student STU_20251105011938_9B3M in course TEST100
# Student TestStudent187 LastName187 added successfully with ID: STU_20251105011938_SGOB
# Grade added for student STU_20251105011938_SGOB in course TEST100
# Student TestStudent188 LastName188 added successfully with ID: STU_20251105011938_9G9O
# Grade added for student STU_20251105011938_9G9O in course TEST100
# Student TestStudent189 LastName189 added successfully with ID: STU_20251105011938_ET53
# Grade added for student STU_20251105011938_ET53 in course TEST100
# Student TestStudent190 LastName190 added successfully with ID: STU_20251105011938_8F3C
# Grade added for student STU_20251105011938_8F3C in course TEST100
# Student TestStudent191 LastName191 added successfully with ID: STU_20251105011938_CIQK
# Grade added for student STU_20251105011938_CIQK in course TEST100
# Student TestStudent192 LastName192 added successfully with ID: STU_20251105011938_2ZA0
# Grade added for student STU_20251105011938_2ZA0 in course TEST100
# Student TestStudent193 LastName193 added successfully with ID: STU_20251105011938_88HW
# Grade added for student STU_20251105011938_88HW in course TEST100
# Student TestStudent194 LastName194 added successfully with ID: STU_20251105011938_6VFW
# Grade added for student STU_20251105011938_6VFW in course TEST100
# Student TestStudent195 LastName195 added successfully with ID: STU_20251105011938_C9HH
# Grade added for student STU_20251105011938_C9HH in course TEST100
# Student TestStudent196 LastName196 added successfully with ID: STU_20251105011938_ZF3U
# Grade added for student STU_20251105011938_ZF3U in course TEST100
# Student TestStudent197 LastName197 added successfully with ID: STU_20251105011938_IYYN
# Grade added for student STU_20251105011938_IYYN in course TEST100
# Student TestStudent198 LastName198 added successfully with ID: STU_20251105011938_44YH
# Grade added for student STU_20251105011938_44YH in course TEST100
# Student TestStudent199 LastName199 added successfully with ID: STU_20251105011938_TEQY
# Grade added for student STU_20251105011938_TEQY in course TEST100
# Student TestStudent200 LastName200 added successfully with ID: STU_20251105011938_FL69
# Grade added for student STU_20251105011938_FL69 in course TEST100
# Student TestStudent201 LastName201 added successfully with ID: STU_20251105011938_P269
# Grade added for student STU_20251105011938_P269 in course TEST100
# Student TestStudent202 LastName202 added successfully with ID: STU_20251105011938_A6TO
# Grade added for student STU_20251105011938_A6TO in course TEST100
# Student TestStudent203 LastName203 added successfully with ID: STU_20251105011938_1O1I
# Grade added for student STU_20251105011938_1O1I in course TEST100
# Student TestStudent204 LastName204 added successfully with ID: STU_20251105011938_K35V
# Grade added for student STU_20251105011938_K35V in course TEST100
# Student TestStudent205 LastName205 added successfully with ID: STU_20251105011938_DHJM
# Grade added for student STU_20251105011938_DHJM in course TEST100
# Student TestStudent206 LastName206 added successfully with ID: STU_20251105011938_ZSAL
# Grade added for student STU_20251105011938_ZSAL in course TEST100
# Student TestStudent207 LastName207 added successfully with ID: STU_20251105011938_LHBG
# Grade added for student STU_20251105011938_LHBG in course TEST100
# Student TestStudent208 LastName208 added successfully with ID: STU_20251105011938_XFJD
# Grade added for student STU_20251105011938_XFJD in course TEST100
# Student TestStudent209 LastName209 added successfully with ID: STU_20251105011938_G1ZG
# Grade added for student STU_20251105011938_G1ZG in course TEST100
# Student TestStudent210 LastName210 added successfully with ID: STU_20251105011938_715K
# Grade added for student STU_20251105011938_715K in course TEST100
# Student TestStudent211 LastName211 added successfully with ID: STU_20251105011938_MFFX
# Grade added for student STU_20251105011938_MFFX in course TEST100
# Student TestStudent212 LastName212 added successfully with ID: STU_20251105011938_REU9
# Grade added for student STU_20251105011938_REU9 in course TEST100
# Student TestStudent213 LastName213 added successfully with ID: STU_20251105011938_39QK
# Grade added for student STU_20251105011938_39QK in course TEST100
# Student TestStudent214 LastName214 added successfully with ID: STU_20251105011938_TLZQ
# Grade added for student STU_20251105011938_TLZQ in course TEST100
# Student TestStudent215 LastName215 added successfully with ID: STU_20251105011938_6O91
# Grade added for student STU_20251105011938_6O91 in course TEST100
# Student TestStudent216 LastName216 added successfully with ID: STU_20251105011938_FTO0
# Grade added for student STU_20251105011938_FTO0 in course TEST100
# Student TestStudent217 LastName217 added successfully with ID: STU_20251105011938_WPX2
# Grade added for student STU_20251105011938_WPX2 in course TEST100
# Student TestStudent218 LastName218 added successfully with ID: STU_20251105011938_2P1J
# Grade added for student STU_20251105011938_2P1J in course TEST100
# Student TestStudent219 LastName219 added successfully with ID: STU_20251105011938_GXXK
# Grade added for student STU_20251105011938_GXXK in course TEST100
# Student TestStudent220 LastName220 added successfully with ID: STU_20251105011938_MBCC
# Grade added for student STU_20251105011938_MBCC in course TEST100
# Student TestStudent221 LastName221 added successfully with ID: STU_20251105011938_E3QN
# Grade added for student STU_20251105011938_E3QN in course TEST100
# Student TestStudent222 LastName222 added successfully with ID: STU_20251105011938_V7Q0
# Grade added for student STU_20251105011938_V7Q0 in course TEST100
# Student TestStudent223 LastName223 added successfully with ID: STU_20251105011938_6C92
# Grade added for student STU_20251105011938_6C92 in course TEST100
# Student TestStudent224 LastName224 added successfully with ID: STU_20251105011938_N00X
# Grade added for student STU_20251105011938_N00X in course TEST100
# Student TestStudent225 LastName225 added successfully with ID: STU_20251105011938_11EJ
# Grade added for student STU_20251105011938_11EJ in course TEST100
# Student TestStudent226 LastName226 added successfully with ID: STU_20251105011938_C8I5
# Grade added for student STU_20251105011938_C8I5 in course TEST100
# Student TestStudent227 LastName227 added successfully with ID: STU_20251105011938_T22F
# Grade added for student STU_20251105011938_T22F in course TEST100
# Student TestStudent228 LastName228 added successfully with ID: STU_20251105011938_5QRJ
# Grade added for student STU_20251105011938_5QRJ in course TEST100
# Student TestStudent229 LastName229 added successfully with ID: STU_20251105011938_5V4J
# Grade added for student STU_20251105011938_5V4J in course TEST100
# Student TestStudent230 LastName230 added successfully with ID: STU_20251105011938_QVLV
# Grade added for student STU_20251105011938_QVLV in course TEST100
# Student TestStudent231 LastName231 added successfully with ID: STU_20251105011938_R5GD
# Grade added for student STU_20251105011938_R5GD in course TEST100
# Student TestStudent232 LastName232 added successfully with ID: STU_20251105011938_UKYH
# Grade added for student STU_20251105011938_UKYH in course TEST100
# Student TestStudent233 LastName233 added successfully with ID: STU_20251105011938_YU21
# Grade added for student STU_20251105011938_YU21 in course TEST100
# Student TestStudent234 LastName234 added successfully with ID: STU_20251105011938_XBJQ
# Grade added for student STU_20251105011938_XBJQ in course TEST100
# Student TestStudent235 LastName235 added successfully with ID: STU_20251105011938_RHVM
# Grade added for student STU_20251105011938_RHVM in course TEST100
# Student TestStudent236 LastName236 added successfully with ID: STU_20251105011938_X78Y
# Grade added for student STU_20251105011938_X78Y in course TEST100
# Student TestStudent237 LastName237 added successfully with ID: STU_20251105011938_SB2L
# Grade added for student STU_20251105011938_SB2L in course TEST100
# Student TestStudent238 LastName238 added successfully with ID: STU_20251105011938_KVHI
# Grade added for student STU_20251105011938_KVHI in course TEST100
# Student TestStudent239 LastName239 added successfully with ID: STU_20251105011938_6HG0
# Grade added for student STU_20251105011938_6HG0 in course TEST100
# Student TestStudent240 LastName240 added successfully with ID: STU_20251105011938_7I27
# Grade added for student STU_20251105011938_7I27 in course TEST100
# Student TestStudent241 LastName241 added successfully with ID: STU_20251105011938_GWN4
# Grade added for student STU_20251105011938_GWN4 in course TEST100
# Student TestStudent242 LastName242 added successfully with ID: STU_20251105011938_1YWP
# Grade added for student STU_20251105011938_1YWP in course TEST100
# Student TestStudent243 LastName243 added successfully with ID: STU_20251105011938_J500
# Grade added for student STU_20251105011938_J500 in course TEST100
# Student TestStudent244 LastName244 added successfully with ID: STU_20251105011938_D5A8
# Grade added for student STU_20251105011938_D5A8 in course TEST100
# Student TestStudent245 LastName245 added successfully with ID: STU_20251105011938_8PYO
# Grade added for student STU_20251105011938_8PYO in course TEST100
# Student TestStudent246 LastName246 added successfully with ID: STU_20251105011938_A9OW
# Grade added for student STU_20251105011938_A9OW in course TEST100
# Student TestStudent247 LastName247 added successfully with ID: STU_20251105011938_DOQB
# Grade added for student STU_20251105011938_DOQB in course TEST100
# Student TestStudent248 LastName248 added successfully with ID: STU_20251105011938_ORLJ
# Grade added for student STU_20251105011938_ORLJ in course TEST100
# Student TestStudent249 LastName249 added successfully with ID: STU_20251105011938_4BT0
# Grade added for student STU_20251105011938_4BT0 in course TEST100
# Student TestStudent250 LastName250 added successfully with ID: STU_20251105011938_KQLH
# Grade added for student STU_20251105011938_KQLH in course TEST100
# Student TestStudent251 LastName251 added successfully with ID: STU_20251105011938_U63X
# Grade added for student STU_20251105011938_U63X in course TEST100
# Student TestStudent252 LastName252 added successfully with ID: STU_20251105011938_D927
# Grade added for student STU_20251105011938_D927 in course TEST100
# Student TestStudent253 LastName253 added successfully with ID: STU_20251105011938_87ZT
# Grade added for student STU_20251105011938_87ZT in course TEST100
# Student TestStudent254 LastName254 added successfully with ID: STU_20251105011938_RS7J
# Grade added for student STU_20251105011938_RS7J in course TEST100
# Student TestStudent255 LastName255 added successfully with ID: STU_20251105011938_7KYQ
# Grade added for student STU_20251105011938_7KYQ in course TEST100
# Student TestStudent256 LastName256 added successfully with ID: STU_20251105011938_76LB
# Grade added for student STU_20251105011938_76LB in course TEST100
# Student TestStudent257 LastName257 added successfully with ID: STU_20251105011938_ECC3
# Grade added for student STU_20251105011938_ECC3 in course TEST100
# Student TestStudent258 LastName258 added successfully with ID: STU_20251105011938_33RT
# Grade added for student STU_20251105011938_33RT in course TEST100
# Student TestStudent259 LastName259 added successfully with ID: STU_20251105011938_JUMH
# Grade added for student STU_20251105011938_JUMH in course TEST100
# Student TestStudent260 LastName260 added successfully with ID: STU_20251105011938_FV35
# Grade added for student STU_20251105011938_FV35 in course TEST100
# Student TestStudent261 LastName261 added successfully with ID: STU_20251105011938_I8C6
# Grade added for student STU_20251105011938_I8C6 in course TEST100
# Student TestStudent262 LastName262 added successfully with ID: STU_20251105011938_IBB6
# Grade added for student STU_20251105011938_IBB6 in course TEST100
# Student TestStudent263 LastName263 added successfully with ID: STU_20251105011938_XTHB
# Grade added for student STU_20251105011938_XTHB in course TEST100
# Student TestStudent264 LastName264 added successfully with ID: STU_20251105011938_I2CR
# Grade added for student STU_20251105011938_I2CR in course TEST100
# Student TestStudent265 LastName265 added successfully with ID: STU_20251105011938_3HBR
# Grade added for student STU_20251105011938_3HBR in course TEST100
# Student TestStudent266 LastName266 added successfully with ID: STU_20251105011938_ZJ06
# ...
# Student Student934 Last65 added successfully with ID: STU_20251105011939_GP58
# Student Student935 Last64 added successfully with ID: STU_20251105011939_TQK8
# Student Student936 Last63 added successfully with ID: STU_20251105011939_IJW1
# Student Student937 Last62 added successfully with ID: STU_20251105011939_9ABB
# Student Student938 Last61 added successfully with ID: STU_20251105011939_00QS
# Student Student939 Last60 added successfully with ID: STU_20251105011939_63OG
# Student Student940 Last59 added successfully with ID: STU_20251105011939_K9PZ
# Student Student941 Last58 added successfully with ID: STU_20251105011939_OA86
# Student Student942 Last57 added successfully with ID: STU_20251105011939_KTM0
# Student Student943 Last56 added successfully with ID: STU_20251105011939_5WOQ
# Student Student944 Last55 added successfully with ID: STU_20251105011939_VR5B
# Student Student945 Last54 added successfully with ID: STU_20251105011939_O8QA
# Student Student946 Last53 added successfully with ID: STU_20251105011939_RKX7
# Student Student947 Last52 added successfully with ID: STU_20251105011939_YYD2
# Student Student948 Last51 added successfully with ID: STU_20251105011939_KDAR
# Student Student949 Last50 added successfully with ID: STU_20251105011939_0YJE
# Student Student950 Last49 added successfully with ID: STU_20251105011939_UF0C
# Student Student951 Last48 added successfully with ID: STU_20251105011939_8VV2
# Student Student952 Last47 added successfully with ID: STU_20251105011939_9YHL
# Student Student953 Last46 added successfully with ID: STU_20251105011939_PMZO
# Student Student954 Last45 added successfully with ID: STU_20251105011939_OJG9
# Student Student955 Last44 added successfully with ID: STU_20251105011939_QFVF
# Student Student956 Last43 added successfully with ID: STU_20251105011939_5NM5
# Student Student957 Last42 added successfully with ID: STU_20251105011939_0ZBP
# Student Student958 Last41 added successfully with ID: STU_20251105011939_Q387
# Student Student959 Last40 added successfully with ID: STU_20251105011939_ZLH7
# Student Student960 Last39 added successfully with ID: STU_20251105011939_Q1L9
# Student Student961 Last38 added successfully with ID: STU_20251105011939_4H77
# Student Student962 Last37 added successfully with ID: STU_20251105011939_TW2C
# Student Student963 Last36 added successfully with ID: STU_20251105011939_JNAR
# Student Student964 Last35 added successfully with ID: STU_20251105011939_7ROG
# Student Student965 Last34 added successfully with ID: STU_20251105011939_BIEP
# Student Student966 Last33 added successfully with ID: STU_20251105011939_L282
# Student Student967 Last32 added successfully with ID: STU_20251105011939_W5JO
# Student Student968 Last31 added successfully with ID: STU_20251105011939_HSJK
# Student Student969 Last30 added successfully with ID: STU_20251105011939_RQ1A
# Student Student970 Last29 added successfully with ID: STU_20251105011939_VJBE
# Student Student971 Last28 added successfully with ID: STU_20251105011939_HOY8
# Student Student972 Last27 added successfully with ID: STU_20251105011939_TPUQ
# Student Student973 Last26 added successfully with ID: STU_20251105011939_W2BI
# Student Student974 Last25 added successfully with ID: STU_20251105011939_DT1K
# Student Student975 Last24 added successfully with ID: STU_20251105011939_1U12
# Student Student976 Last23 added successfully with ID: STU_20251105011939_YMJD
# Student Student977 Last22 added successfully with ID: STU_20251105011939_YBHT
# Student Student978 Last21 added successfully with ID: STU_20251105011939_Y1QC
# Student Student979 Last20 added successfully with ID: STU_20251105011939_2YB6
# Student Student980 Last19 added successfully with ID: STU_20251105011939_8ZTX
# Student Student981 Last18 added successfully with ID: STU_20251105011939_5DQF
# Student Student982 Last17 added successfully with ID: STU_20251105011939_KMPN
# Student Student983 Last16 added successfully with ID: STU_20251105011939_DNC1
# Student Student984 Last15 added successfully with ID: STU_20251105011939_LUU4
# Student Student985 Last14 added successfully with ID: STU_20251105011939_DPVO
# Student Student986 Last13 added successfully with ID: STU_20251105011939_KQG5
# Student Student987 Last12 added successfully with ID: STU_20251105011939_74PZ
# Student Student988 Last11 added successfully with ID: STU_20251105011939_Y6QV
# Student Student989 Last10 added successfully with ID: STU_20251105011939_HKBJ
# Student Student990 Last9 added successfully with ID: STU_20251105011939_7F5W
# Student Student991 Last8 added successfully with ID: STU_20251105011939_VKQM
# Student Student992 Last7 added successfully with ID: STU_20251105011939_PG9B
# Student Student993 Last6 added successfully with ID: STU_20251105011939_YIM4
# Student Student994 Last5 added successfully with ID: STU_20251105011939_REOU
# Student Student995 Last4 added successfully with ID: STU_20251105011939_9V14
# Student Student996 Last3 added successfully with ID: STU_20251105011939_P2UN
# Student Student997 Last2 added successfully with ID: STU_20251105011939_DKG8
# Student Student998 Last1 added successfully with ID: STU_20251105011939_MJAZ
# Student Student999 Last0 added successfully with ID: STU_20251105011939_LLPQ
# ok
# test_09_course_operations (__main__.TestCheckMyGradeApp.test_09_course_operations)
# Test course add/delete/modify operations ... ok
# ✓ 1000 students sorted by name
# Execution time: 220.06 milliseconds
# Course Data Structures added successfully
# Grade added for student STU_20251105011939_NA3R in course DATA200
# Grade added for student STU_20251105011939_UWEJ in course DATA200
# Grade added for student STU_20251105011939_9UR7 in course DATA200
# Grade added for student STU_20251105011939_N2XZ in course DATA200
# Grade added for student STU_20251105011939_B5CL in course DATA200
# Grade added for student STU_20251105011939_X1VS in course DATA200
# Grade added for student STU_20251105011939_1KCP in course DATA200
# Grade added for student STU_20251105011939_OY5S in course DATA200
# Grade added for student STU_20251105011939_QTWH in course DATA200
# Grade added for student STU_20251105011939_B6CO in course DATA200
# Grade added for student STU_20251105011939_40WI in course DATA200
# Grade added for student STU_20251105011939_BJKR in course DATA200
# Grade added for student STU_20251105011939_ZY8R in course DATA200
# Grade added for student STU_20251105011939_IWGY in course DATA200
# Grade added for student STU_20251105011939_FRD2 in course DATA200
# Grade added for student STU_20251105011939_7J7L in course DATA200
# Grade added for student STU_20251105011939_XC1X in course DATA200
# Grade added for student STU_20251105011939_6RCU in course DATA200
# Grade added for student STU_20251105011939_D3KQ in course DATA200
# Grade added for student STU_20251105011939_38E1 in course DATA200
# Grade added for student STU_20251105011939_3Q45 in course DATA200
# Grade added for student STU_20251105011939_SOGI in course DATA200
# Grade added for student STU_20251105011939_6UY7 in course DATA200
# Grade added for student STU_20251105011939_A6BE in course DATA200
# Grade added for student STU_20251105011939_3BUK in course DATA200
# Grade added for student STU_20251105011939_6N8A in course DATA200
# Grade added for student STU_20251105011939_VNVG in course DATA200
# Grade added for student STU_20251105011939_XGRP in course DATA200
# Grade added for student STU_20251105011939_HKAT in course DATA200
# Grade added for student STU_20251105011939_CTHO in course DATA200
# Grade added for student STU_20251105011939_REVB in course DATA200
# Grade added for student STU_20251105011939_OIYP in course DATA200
# Grade added for student STU_20251105011939_YXIH in course DATA200
# Grade added for student STU_20251105011939_46ZQ in course DATA200
# Grade added for student STU_20251105011939_TY57 in course DATA200
# Grade added for student STU_20251105011939_3HFQ in course DATA200
# Grade added for student STU_20251105011939_YY1Z in course DATA200
# Grade added for student STU_20251105011939_LI6W in course DATA200
# Grade added for student STU_20251105011939_4OD3 in course DATA200
# Grade added for student STU_20251105011939_3USZ in course DATA200
# Grade added for student STU_20251105011939_F0ZE in course DATA200
# Grade added for student STU_20251105011939_YQ84 in course DATA200
# Grade added for student STU_20251105011939_4VZ3 in course DATA200
# Grade added for student STU_20251105011939_D1QQ in course DATA200
# Grade added for student STU_20251105011939_MOXE in course DATA200
# Grade added for student STU_20251105011939_H0HU in course DATA200
# Grade added for student STU_20251105011939_95JK in course DATA200
# Grade added for student STU_20251105011939_NBG6 in course DATA200
# Grade added for student STU_20251105011939_O73K in course DATA200
# Grade added for student STU_20251105011939_G98G in course DATA200
# Grade added for student STU_20251105011939_1A79 in course DATA200
# Grade added for student STU_20251105011939_W2JQ in course DATA200
# Grade added for student STU_20251105011939_IJZS in course DATA200
# Grade added for student STU_20251105011939_47KY in course DATA200
# Grade added for student STU_20251105011939_06M7 in course DATA200
# Grade added for student STU_20251105011939_4Y2H in course DATA200
# Grade added for student STU_20251105011939_R94J in course DATA200
# Grade added for student STU_20251105011939_53NR in course DATA200
# Grade added for student STU_20251105011939_ZTDJ in course DATA200
# Grade added for student STU_20251105011939_0U2Z in course DATA200
# Grade added for student STU_20251105011939_WGBW in course DATA200
# Grade added for student STU_20251105011939_TXJV in course DATA200
# Grade added for student STU_20251105011939_QOWK in course DATA200
# Grade added for student STU_20251105011939_PJ9F in course DATA200
# Grade added for student STU_20251105011939_QY9H in course DATA200
# Grade added for student STU_20251105011939_FAWI in course DATA200
# Grade added for student STU_20251105011939_IPXJ in course DATA200
# Grade added for student STU_20251105011939_QWDS in course DATA200
# Grade added for student STU_20251105011939_MQO6 in course DATA200
# Grade added for student STU_20251105011939_79Y5 in course DATA200
# Grade added for student STU_20251105011939_0TZW in course DATA200
# Grade added for student STU_20251105011939_DFT8 in course DATA200
# Grade added for student STU_20251105011939_8PMI in course DATA200
# Grade added for student STU_20251105011939_9VW2 in course DATA200
# Grade added for student STU_20251105011939_D9G9 in course DATA200
# Grade added for student STU_20251105011939_WZ33 in course DATA200
# Grade added for student STU_20251105011939_WX4J in course DATA200
# Grade added for student STU_20251105011939_W58B in course DATA200
# Grade added for student STU_20251105011939_VAW8 in course DATA200
# Grade added for student STU_20251105011939_T4HI in course DATA200
# Grade added for student STU_20251105011939_O1RB in course DATA200
# Grade added for student STU_20251105011939_7UVE in course DATA200
# Grade added for student STU_20251105011939_Z76S in course DATA200
# Grade added for student STU_20251105011939_87W0 in course DATA200
# Grade added for student STU_20251105011939_K1C7 in course DATA200
# Grade added for student STU_20251105011939_NSTF in course DATA200
# Grade added for student STU_20251105011939_PY1U in course DATA200
# Grade added for student STU_20251105011939_C8HI in course DATA200
# Grade added for student STU_20251105011939_U9AU in course DATA200
# Grade added for student STU_20251105011939_CXMN in course DATA200
# Grade added for student STU_20251105011939_5MI1 in course DATA200
# Grade added for student STU_20251105011939_TEO1 in course DATA200
# Grade added for student STU_20251105011939_VZLD in course DATA200
# Grade added for student STU_20251105011939_ZU2L in course DATA200
# Grade added for student STU_20251105011939_ZK98 in course DATA200
# Grade added for student STU_20251105011939_LIT2 in course DATA200
# Grade added for student STU_20251105011939_5URQ in course DATA200
# Grade added for student STU_20251105011939_4752 in course DATA200
# Grade added for student STU_20251105011939_K6QA in course DATA200
# Grade added for student STU_20251105011939_HNXL in course DATA200
# ✓ 1000 students sorted by marks
# Execution time: 201.31 milliseconds
#
# ============================================================
# TEST 9: Course Operations (Add/Delete/Modify)
# ============================================================
# Course Machine Learning added successfully
# ✓ Course added - Time: 0.0145 ms
# Course DATA201 updated successfully
# ✓ Course modified - Time: 0.0141 ms
# Course DATA201 deleted successfully
# ✓ Course deleted - Time: 0.0141 ms
# test_10_professor_operations (__main__.TestCheckMyGradeApp.test_10_professor_operations)
# Test professor add/delete/modify operations ... ok
# test_11_file_operations (__main__.TestCheckMyGradeApp.test_11_file_operations)
# Test CSV file save and load operations ... ok
# test_12_statistics (__main__.TestCheckMyGradeApp.test_12_statistics)
# Test course statistics calculation ... ok
# test_13_password_encryption (__main__.TestCheckMyGradeApp.test_13_password_encryption)
# Test password encryption and verification ... ok
#
# ======================================================================
# FAIL: test_07_sort_by_marks (__main__.TestCheckMyGradeApp.test_07_sort_by_marks)
# Test sorting students by marks
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/tmp/ipython-input-1675080776.py", line 838, in test_07_sort_by_marks
#     self.assertEqual(self.app.students[0].first_name, "Bob")
# AssertionError: 'Charlie' != 'Bob'
# - Charlie
# + Bob
#
#
# ----------------------------------------------------------------------
# Ran 13 tests in 0.643s
#
# FAILED (failures=1)
# ============================================================
# TEST 10: Professor Operations (Add/Delete/Modify)
# ============================================================
# Course Data Structures added successfully
# Professor Dr. John Smith added successfully with ID: PROF_20251105011939_XSVD
# ✓ Professor added - Time: 0.0679 ms
# Professor PROF_20251105011939_XSVD updated successfully
# ✓ Professor modified - Time: 0.0138 ms
# Professor PROF_20251105011939_XSVD deleted successfully
# ✓ Professor deleted - Time: 0.0114 ms
#
# ============================================================
# TEST 11: CSV File Operations (Save/Load)
# ============================================================
# Course Data Structures added successfully
# Student Test Student added successfully with ID: STU_20251105011939_THVB
# Professor Dr. Test added successfully with ID: PROF_20251105011939_F6BM
# Grade added for student STU_20251105011939_THVB in course DATA200
# Students saved to students.csv
# Courses saved to courses.csv
# Professors saved to professors.csv
# No users to save
#
# All data saved successfully!
# ✓ All data saved - Time: 0.6385 ms
# Students loaded from students.csv
# Courses loaded from courses.csv
# Professors loaded from professors.csv
# File login.csv not found
#
# All data loaded successfully!
# ✓ All data loaded - Time: 1.5843 ms
#
# ============================================================
# TEST 12: Course Statistics (Average/Median)
# ============================================================
# Course Data Structures added successfully
# Student Student1 Last1 added successfully with ID: STU_20251105011939_JD9C
# Student Student2 Last2 added successfully with ID: STU_20251105011939_81R1
# Student Student3 Last3 added successfully with ID: STU_20251105011939_AS16
# Grade added for student STU_20251105011939_JD9C in course DATA200
# Grade added for student STU_20251105011939_81R1 in course DATA200
# Grade added for student STU_20251105011939_AS16 in course DATA200
# ✓ Statistics calculated
#   Average: 80.0
#   Median: 80
#   Count: 3
# Execution time: 0.0291 ms
#
# ============================================================
# TEST 13: Password Encryption and Login
# ============================================================
# ✓ Password encrypted - Time: 0.0319 ms
# Original password: Welcome12#_
# Encrypted hash: 07621553b734e6ab6c84f6969f071614...
# Login successful! Welcome test@user.com
# ✓ Login successful - Time: 0.0107 ms
# Invalid password
# ✓ Invalid login rejected correctly
